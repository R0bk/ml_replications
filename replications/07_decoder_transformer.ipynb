# %% [markdown]
# <a href="https://colab.research.google.com/github/R0bk/ml_replications/blob/main/07_decoder_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

tiny_shake = requests.get('https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt').text
print(tiny_shake[:300])
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You are all resolved rather to die than to famish?
#
# All:
# Resolved. resolved.
#
# First Citizen:
# First, you know Caius Marcius is chief enemy to the people.
#
# All:
# We know't, we know't.
#
# First Citizen:
# Let us

# %%
import torch

vocab = sorted(list(set(tiny_shake)))
vocab_size = len(vocab)
print(f'Len of vocab: {vocab_size}, vocab: {"".join(vocab)}')

vocab2id = {x: i for i, x in enumerate(vocab)}
id2vocab = {i: x for i, x in enumerate(vocab)}

encode = lambda x: torch.tensor([vocab2id[y] for y in x])
decode = lambda x: ''.join(id2vocab[int(y)] for y in x)
# Out:
# Len of vocab: 65, vocab:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz

# %%
tt_split = int(0.9*len(tiny_shake))

train_shake = tiny_shake[:tt_split]
val_shake = tiny_shake[tt_split:]

# %%
max_seq_len = 8


def get_batch(data: list[int], b: int, seq_len: int):
    idx = torch.randint(len(data)-(seq_len+1), (b,))
    xb = torch.stack([data[i:i+seq_len] for i in idx])
    yb = torch.stack([data[i+1:i+seq_len+1] for i in idx])
    return xb, yb

x, y = get_batch(encode(train_shake), 4, max_seq_len)
print(x)
for i, y in enumerate(x):
    print(i, decode(y))

x.shape
def split_batch(batch):
    seq_len = batch.shape[1] # (b, seqlen)
    for i in range(1, seq_len):
        x, y = batch[:, :i], batch[:, i:i+1]
        yield x, y


split_batch(x)
# Out:
# tensor([[58,  1, 45, 56, 39, 41, 47, 53],
#         [10,  0, 32, 46, 43,  1, 41, 59],
#         [50, 50,  1, 46, 43,  1, 41, 53],
#         [ 1, 39, 51,  1, 39, 44, 44, 47]])
# 0 t gracio
# 1 :
# The cu
# 2 ll he co
# 3  am affi
# <generator object split_batch at 0x7fc7345f2740>

# %%
import torch.nn.functional as F
from torch import nn

class BigramModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, vocab_size)

    def forward(self, x, y=None):
        x = self.embedding(x) # (b, seqlen) -> (b, seqlen, vocabsize)
        
        if y is None:
            return x

        B, T, C = x.shape
        x = x.view(B*T, C)
        y = y.view(-1)
        
        loss = F.cross_entropy(x, y)

        return x, loss

    def prompt(self, pmt: str, mtkn: int):
        x = encode(pmt).unsqueeze(0)
        print(x)

        for i in range(mtkn):
            newx = self(x) # (B, T C)
            newx = newx[:, -1, :] # (B, 1, C)
            
            probs = F.softmax(newx, dim=-1)
            
            newx = torch.multinomial(probs, num_samples=1) # (B, 1)

            x = torch.cat([x, newx], axis=1)
        return decode(x[0])


m = BigramModel(len(vocab))

# %%
m.prompt('Hi', 50)
# Out:
# tensor([[20, 47]])
# "Hi LLG\nOQ$cZ3fXnORhv'skcpC.NxIs ,WpeFei.ZAvph\n !e&av"

# %%
print(m.prompt('Hi', 150))
# Out:
# tensor([[20, 47]])
# HitcKsAqg-ovndQ?yT&v&m:hrPyNdPhwD-;J&KyiTyi..ZZxhe:huTyYXNQJ.Cmm.qUTrXHsJx,ffpC-yzMHpzIe'x!UAVlW3lFwH.-BNPYQoMUJtfZ; $?swovl$HqIbg,CQjsw &P.$ck
# HbruNtQZ

# %%
x, y = get_batch(encode(train_shake), 1, max_seq_len)
print(x, y)
x, l = m(x, y)
print(l)
# Out:
# tensor([[39, 56, 43,  1, 44, 47, 58,  1]]) tensor([[56, 43,  1, 44, 47, 58,  1, 58]])
# tensor(4.0485, grad_fn=<NllLossBackward0>)

# %%
x = get_batch(encode(train_shake), 1, max_seq_len)
print(x)
out = decode(x[0])
print(out)

nsteps = 100
for i in range(nsteps):
    x = torch.cat([x, torch.argmax(m(x)).view(1,1)], axis=1)

print(decode(x[0]))
# Out:
# (tensor([[58, 46, 47, 52, 49,  1, 63, 53]]), tensor([[46, 47, 52, 49,  1, 63, 53, 59]]))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-5c11304f21f2> in <cell line: 3>()
#       1 x = get_batch(encode(train_shake), 1, max_seq_len)
#       2 print(x)
# ----> 3 out = decode(x[0])
#       4 print(out)
#       5
#
# <ipython-input-2-6df9bb66c564> in <lambda>(x)
#       8
#       9 encode = lambda x: torch.tensor([vocab2id[y] for y in x])
# ---> 10 decode = lambda x: ''.join(id2vocab[int(y)] for y in x)
#
# <ipython-input-2-6df9bb66c564> in <genexpr>(.0)
#       8
#       9 encode = lambda x: torch.tensor([vocab2id[y] for y in x])
# ---> 10 decode = lambda x: ''.join(id2vocab[int(y)] for y in x)
#
# ValueError: only one element tensors can be converted to Python scalars

# %%
lr = 1e-4
optim = torch.optim.AdamW(m.parameters())

# %%
steps = 100

for t in range(steps):
    xb, yb = get_batch(encode(train_shake), 32, max_seq_len)

    output, loss = m(xb, yb)
    optim.zero_grad()
    loss.backward()
    print(loss)

    optim.step()
# Out:
# tensor(4.5281, grad_fn=<NllLossBackward0>)
# tensor(4.6831, grad_fn=<NllLossBackward0>)
# tensor(4.5577, grad_fn=<NllLossBackward0>)
# tensor(4.5618, grad_fn=<NllLossBackward0>)
# tensor(4.4680, grad_fn=<NllLossBackward0>)
# tensor(4.5053, grad_fn=<NllLossBackward0>)
# tensor(4.5063, grad_fn=<NllLossBackward0>)
# tensor(4.4562, grad_fn=<NllLossBackward0>)
# tensor(4.5525, grad_fn=<NllLossBackward0>)
# tensor(4.4821, grad_fn=<NllLossBackward0>)
# tensor(4.5869, grad_fn=<NllLossBackward0>)
# tensor(4.6048, grad_fn=<NllLossBackward0>)
# tensor(4.5572, grad_fn=<NllLossBackward0>)
# tensor(4.5717, grad_fn=<NllLossBackward0>)
# tensor(4.4437, grad_fn=<NllLossBackward0>)
# tensor(4.4187, grad_fn=<NllLossBackward0>)
# tensor(4.5367, grad_fn=<NllLossBackward0>)
# tensor(4.5730, grad_fn=<NllLossBackward0>)
# tensor(4.5213, grad_fn=<NllLossBackward0>)
# tensor(4.4505, grad_fn=<NllLossBackward0>)
# tensor(4.4537, grad_fn=<NllLossBackward0>)
# tensor(4.5617, grad_fn=<NllLossBackward0>)
# tensor(4.4751, grad_fn=<NllLossBackward0>)
# tensor(4.5124, grad_fn=<NllLossBackward0>)
# tensor(4.5852, grad_fn=<NllLossBackward0>)
# tensor(4.6533, grad_fn=<NllLossBackward0>)
# tensor(4.4256, grad_fn=<NllLossBackward0>)
# tensor(4.4886, grad_fn=<NllLossBackward0>)
# tensor(4.5963, grad_fn=<NllLossBackward0>)
# tensor(4.5702, grad_fn=<NllLossBackward0>)
# tensor(4.5116, grad_fn=<NllLossBackward0>)
# tensor(4.4664, grad_fn=<NllLossBackward0>)
# tensor(4.4988, grad_fn=<NllLossBackward0>)
# tensor(4.5466, grad_fn=<NllLossBackward0>)
# tensor(4.5051, grad_fn=<NllLossBackward0>)
# tensor(4.4614, grad_fn=<NllLossBackward0>)
# tensor(4.5929, grad_fn=<NllLossBackward0>)
# tensor(4.4506, grad_fn=<NllLossBackward0>)
# tensor(4.5629, grad_fn=<NllLossBackward0>)
# tensor(4.4875, grad_fn=<NllLossBackward0>)
# tensor(4.4250, grad_fn=<NllLossBackward0>)
# tensor(4.4688, grad_fn=<NllLossBackward0>)
# tensor(4.4783, grad_fn=<NllLossBackward0>)
# tensor(4.5084, grad_fn=<NllLossBackward0>)
# tensor(4.5404, grad_fn=<NllLossBackward0>)
# tensor(4.5072, grad_fn=<NllLossBackward0>)
# tensor(4.4610, grad_fn=<NllLossBackward0>)
# tensor(4.4060, grad_fn=<NllLossBackward0>)
# tensor(4.4267, grad_fn=<NllLossBackward0>)
# tensor(4.5534, grad_fn=<NllLossBackward0>)
# tensor(4.4687, grad_fn=<NllLossBackward0>)
# tensor(4.5048, grad_fn=<NllLossBackward0>)
# tensor(4.5028, grad_fn=<NllLossBackward0>)
# tensor(4.5531, grad_fn=<NllLossBackward0>)
# tensor(4.4155, grad_fn=<NllLossBackward0>)
# tensor(4.3948, grad_fn=<NllLossBackward0>)
# tensor(4.4286, grad_fn=<NllLossBackward0>)
# tensor(4.4798, grad_fn=<NllLossBackward0>)
# tensor(4.4093, grad_fn=<NllLossBackward0>)
# tensor(4.5519, grad_fn=<NllLossBackward0>)
# tensor(4.4101, grad_fn=<NllLossBackward0>)
# tensor(4.5214, grad_fn=<NllLossBackward0>)
# tensor(4.5360, grad_fn=<NllLossBackward0>)
# tensor(4.4266, grad_fn=<NllLossBackward0>)
# tensor(4.4493, grad_fn=<NllLossBackward0>)
# tensor(4.4384, grad_fn=<NllLossBackward0>)
# tensor(4.4986, grad_fn=<NllLossBackward0>)
# tensor(4.3964, grad_fn=<NllLossBackward0>)
# tensor(4.4473, grad_fn=<NllLossBackward0>)
# tensor(4.3865, grad_fn=<NllLossBackward0>)
# tensor(4.4990, grad_fn=<NllLossBackward0>)
# tensor(4.5562, grad_fn=<NllLossBackward0>)
# tensor(4.5193, grad_fn=<NllLossBackward0>)
# tensor(4.4039, grad_fn=<NllLossBackward0>)
# tensor(4.5747, grad_fn=<NllLossBackward0>)
# tensor(4.4992, grad_fn=<NllLossBackward0>)
# tensor(4.4172, grad_fn=<NllLossBackward0>)
# tensor(4.4512, grad_fn=<NllLossBackward0>)
# tensor(4.4398, grad_fn=<NllLossBackward0>)
# tensor(4.4813, grad_fn=<NllLossBackward0>)
# tensor(4.4386, grad_fn=<NllLossBackward0>)
# tensor(4.4124, grad_fn=<NllLossBackward0>)
# tensor(4.3922, grad_fn=<NllLossBackward0>)
# tensor(4.4474, grad_fn=<NllLossBackward0>)
# tensor(4.4014, grad_fn=<NllLossBackward0>)
# tensor(4.4481, grad_fn=<NllLossBackward0>)
# tensor(4.5039, grad_fn=<NllLossBackward0>)
# tensor(4.3474, grad_fn=<NllLossBackward0>)
# tensor(4.4280, grad_fn=<NllLossBackward0>)
# tensor(4.4142, grad_fn=<NllLossBackward0>)
# tensor(4.5048, grad_fn=<NllLossBackward0>)
# tensor(4.5184, grad_fn=<NllLossBackward0>)
# tensor(4.4125, grad_fn=<NllLossBackward0>)
# tensor(4.5369, grad_fn=<NllLossBackward0>)
# tensor(4.4507, grad_fn=<NllLossBackward0>)
# tensor(4.3856, grad_fn=<NllLossBackward0>)
# tensor(4.4656, grad_fn=<NllLossBackward0>)
# tensor(4.4583, grad_fn=<NllLossBackward0>)
# tensor(4.3959, grad_fn=<NllLossBackward0>)
# tensor(4.4857, grad_fn=<NllLossBackward0>)

# %%
B, S, E = 2, 4, 6
# Version 1
x = torch.rand((B, S, E))

xsum = x.clone()
for tokeni in range(1, S):
    xsum[:, tokeni, :] += xsum[:, tokeni-1, :]


# Version 2
x = torch.randint(10, (B,S,E), dtype=torch.float).transpose(1,2)
wei = torch.triu(torch.ones((S,S)))
wei = wei / wei.sum(dim=0)
xavg = x @ wei


# Version 3
x = torch.randint(10, (B,S,E), dtype=torch.float)
print(x)
wei = torch.zeros((S,S))
wei = wei.masked_fill(torch.tril(torch.ones(S,S))==0, float('-inf'))
wei = F.softmax(wei, dim=-1)
print(wei)
print(wei.shape, x.shape)
print(wei @ x)

# Version 4, self atteniton, single head
head_size = 16

x = torch.rand((B,S,E))

key = nn.Linear(E, head_size, bias=False)
query = nn.Linear(E, head_size, bias=False)
value = nn.Linear(E, head_size, bias=False)

k = key(x) # (B,T,E)->(B,T,head_size)
q = query(x) # (B,T,E)->(B,T,head_size)

wei = q @ k.transpose(1,2) # (B, T, T)
wei = wei / head_size**-0.5

wei = wei.masked_fill(torch.tril(torch.ones(S,S))==0, float('-inf'))
wei = F.softmax(wei, dim=-1)
print(wei)
print(wei.shape, x.shape)
wei

v = value(x) # (B,T,E)->(B,T,head_size)

out = wei @ v # (B,T,T) @ (B,T,E) -> (B, T, E)
# Out:
# tensor([[[7., 7., 2., 5., 5., 7.],
#          [9., 6., 1., 3., 1., 1.],
#          [8., 4., 8., 9., 9., 4.],
#          [9., 7., 4., 9., 9., 2.]],
#
#         [[4., 6., 6., 1., 7., 2.],
#          [0., 8., 7., 8., 3., 5.],
#          [6., 3., 7., 7., 8., 5.],
#          [4., 5., 2., 0., 2., 4.]]])
# tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500]])
# torch.Size([4, 4]) torch.Size([2, 4, 6])
# tensor([[[7.0000, 7.0000, 2.0000, 5.0000, 5.0000, 7.0000],
#          [8.0000, 6.5000, 1.5000, 4.0000, 3.0000, 4.0000],
#          [8.0000, 5.6667, 3.6667, 5.6667, 5.0000, 4.0000],
#          [8.2500, 6.0000, 3.7500, 6.5000, 6.0000, 3.5000]],
#
#         [[4.0000, 6.0000, 6.0000, 1.0000, 7.0000, 2.0000],
#          [2.0000, 7.0000, 6.5000, 4.5000, 5.0000, 3.5000],
#          [3.3333, 5.6667, 6.6667, 5.3333, 6.0000, 4.0000],
#          [3.5000, 5.5000, 5.5000, 4.0000, 5.0000, 4.0000]]])
# tensor([[[1.0000, 0.0000, 0.0000, 0.0000],
#          [0.7066, 0.2934, 0.0000, 0.0000],
#          [0.1883, 0.0792, 0.7325, 0.0000],
#          [0.0635, 0.0188, 0.3855, 0.5322]],
#
#         [[1.0000, 0.0000, 0.0000, 0.0000],
#          [0.4563, 0.5437, 0.0000, 0.0000],
#          [0.3487, 0.4170, 0.2343, 0.0000],
#          [0.4165, 0.3294, 0.1225, 0.1316]]], grad_fn=<SoftmaxBackward0>)
# torch.Size([2, 4, 4]) torch.Size([2, 4, 6])

# %%
n_embed = 32
block_size = 32
max_seq_len = 32
# head_size = 16

class Head(nn.Module):

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embed, head_size, bias=False)
        self.query = nn.Linear(n_embed, head_size, bias=False)
        self.value = nn.Linear(n_embed, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

    def forward(self, x):
        B, T, E = x.shape

        k = self.key(x) # (B,T,head_size)
        q = self.query(x) # (B,T,head_size)
        v = self.value(x) # (B,T,head_size)

        wei = q @ k.transpose(1, 2) # (B,T,T)
        wei = wei * head_size**-0.5
        wei = wei.masked_fill(self.tril[:T, :T]==0, float('-inf'))
        wei = F.softmax(wei, dim=-1)

        return wei @ v # (B,T,T) @ (B,T,head_size) -> (B, T, head_size)


class MultiHeadAttention(nn.Module):

    def __init__(self, head_size, head_count):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(head_count)])
        self.proj = nn.Linear(n_embed, n_embed)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1) # (B, T, head_size*head_count)
        return self.proj(out)


class FeedForward(nn.Module):
    
    def __init__(self, n_embed):
        super().__init__()
        self.l1 = nn.Linear(n_embed, 4*n_embed)
        self.proj = nn.Linear(4*n_embed, n_embed)

    def forward(self, x):
        x = self.l1(x)
        x = F.relu(x)
        return self.proj(x)

class Block(nn.Module):

    def __init__(self, n_embed, n_head):
        super().__init__()
        head_size = n_embed//n_head
        self.sa_head = MultiHeadAttention(head_size, n_head)
        self.ffwd = FeedForward(n_embed)
        self.lnorm1 = nn.LayerNorm(n_embed)
        self.lnorm2 = nn.LayerNorm(n_embed)


    def forward(self, x):
        x = x + self.sa_head(self.lnorm1(x)) # (B, T, head_size*head_count==n_embed)
        x = x + self.ffwd(self.lnorm2(x))
        return x

class BigramModel(nn.Module):

    def __init__(self):
        super().__init__()
        self.token_embedding = nn.Embedding(vocab_size, n_embed)
        self.pos_embedding = nn.Embedding(block_size, n_embed)
        self.blocks = nn.Sequential(
            Block(n_embed, 4),
            Block(n_embed, 4),
            Block(n_embed, 4),
            nn.LayerNorm(n_embed)
        )
        self.lm_head = nn.Linear(n_embed, vocab_size)

    def forward(self, x, y=None):
        B, T = x.shape
        
        token_embed = self.token_embedding(x) # (B, T) -> (B, T, n_embed)
        pos_embed = self.pos_embedding(torch.arange(T))
        x = token_embed + pos_embed
        x = self.blocks(x)
        

        logits = self.lm_head(x) # (B, T, n_embed) -> (B, T, vocab_size)
        
        if y is None:
            return logits

        B, T, C = logits.shape
        logits = logits.view(B*T, C)
        y = y.view(-1)
        
        loss = F.cross_entropy(logits, y)

        return logits, loss

    def prompt(self, pmt: str, mtkn: int):
        x = encode(pmt).unsqueeze(0)
        print(x)

        for i in range(mtkn):
            x_cond = x[:, -block_size:]

            newx = self(x_cond) # (B, T C)

            newx = newx[:, -1, :] # (B, 1, C)
            
            probs = F.softmax(newx, dim=-1)
            
            newx = torch.multinomial(probs, num_samples=1) # (B, 1)

            x = torch.cat([x, newx], axis=1)
        return decode(x[0])


m = BigramModel()

# %%
lr = 3e-4
optim = torch.optim.AdamW(m.parameters())

steps = 2500

for t in range(steps):
    xb, yb = get_batch(encode(train_shake), 32, max_seq_len)

    output, loss = m(xb, yb)
    optim.zero_grad()
    loss.backward()
    print(t, loss)

    optim.step()
# Out:
# 0 tensor(4.3447, grad_fn=<NllLossBackward0>)
# 1 tensor(4.2665, grad_fn=<NllLossBackward0>)
# 2 tensor(4.2109, grad_fn=<NllLossBackward0>)
# 3 tensor(4.1300, grad_fn=<NllLossBackward0>)
# 4 tensor(4.1077, grad_fn=<NllLossBackward0>)
# 5 tensor(4.0284, grad_fn=<NllLossBackward0>)
# 6 tensor(3.9783, grad_fn=<NllLossBackward0>)
# 7 tensor(3.9293, grad_fn=<NllLossBackward0>)
# 8 tensor(3.8856, grad_fn=<NllLossBackward0>)
# 9 tensor(3.8378, grad_fn=<NllLossBackward0>)
# 10 tensor(3.7974, grad_fn=<NllLossBackward0>)
# 11 tensor(3.8055, grad_fn=<NllLossBackward0>)
# 12 tensor(3.7279, grad_fn=<NllLossBackward0>)
# 13 tensor(3.7594, grad_fn=<NllLossBackward0>)
# 14 tensor(3.6441, grad_fn=<NllLossBackward0>)
# 15 tensor(3.6660, grad_fn=<NllLossBackward0>)
# 16 tensor(3.6011, grad_fn=<NllLossBackward0>)
# 17 tensor(3.5662, grad_fn=<NllLossBackward0>)
# 18 tensor(3.5600, grad_fn=<NllLossBackward0>)
# 19 tensor(3.5942, grad_fn=<NllLossBackward0>)
# 20 tensor(3.5567, grad_fn=<NllLossBackward0>)
# 21 tensor(3.5351, grad_fn=<NllLossBackward0>)
# 22 tensor(3.4796, grad_fn=<NllLossBackward0>)
# 23 tensor(3.3954, grad_fn=<NllLossBackward0>)
# 24 tensor(3.4092, grad_fn=<NllLossBackward0>)
# 25 tensor(3.4385, grad_fn=<NllLossBackward0>)
# 26 tensor(3.4368, grad_fn=<NllLossBackward0>)
# 27 tensor(3.4048, grad_fn=<NllLossBackward0>)
# 28 tensor(3.4896, grad_fn=<NllLossBackward0>)
# 29 tensor(3.4046, grad_fn=<NllLossBackward0>)
# 30 tensor(3.3708, grad_fn=<NllLossBackward0>)
# 31 tensor(3.3884, grad_fn=<NllLossBackward0>)
# 32 tensor(3.4118, grad_fn=<NllLossBackward0>)
# 33 tensor(3.3613, grad_fn=<NllLossBackward0>)
# 34 tensor(3.3363, grad_fn=<NllLossBackward0>)
# 35 tensor(3.3827, grad_fn=<NllLossBackward0>)
# 36 tensor(3.4430, grad_fn=<NllLossBackward0>)
# 37 tensor(3.2843, grad_fn=<NllLossBackward0>)
# 38 tensor(3.3603, grad_fn=<NllLossBackward0>)
# 39 tensor(3.3472, grad_fn=<NllLossBackward0>)
# 40 tensor(3.3459, grad_fn=<NllLossBackward0>)
# 41 tensor(3.3270, grad_fn=<NllLossBackward0>)
# 42 tensor(3.2348, grad_fn=<NllLossBackward0>)
# 43 tensor(3.3987, grad_fn=<NllLossBackward0>)
# 44 tensor(3.3190, grad_fn=<NllLossBackward0>)
# 45 tensor(3.3193, grad_fn=<NllLossBackward0>)
# 46 tensor(3.3065, grad_fn=<NllLossBackward0>)
# 47 tensor(3.2178, grad_fn=<NllLossBackward0>)
# 48 tensor(3.2829, grad_fn=<NllLossBackward0>)
# 49 tensor(3.2149, grad_fn=<NllLossBackward0>)
# 50 tensor(3.2020, grad_fn=<NllLossBackward0>)
# 51 tensor(3.2323, grad_fn=<NllLossBackward0>)
# 52 tensor(3.3386, grad_fn=<NllLossBackward0>)
# 53 tensor(3.2450, grad_fn=<NllLossBackward0>)
# 54 tensor(3.3642, grad_fn=<NllLossBackward0>)
# 55 tensor(3.2339, grad_fn=<NllLossBackward0>)
# 56 tensor(3.3515, grad_fn=<NllLossBackward0>)
# 57 tensor(3.1337, grad_fn=<NllLossBackward0>)
# 58 tensor(3.2633, grad_fn=<NllLossBackward0>)
# 59 tensor(3.2097, grad_fn=<NllLossBackward0>)
# 60 tensor(3.2133, grad_fn=<NllLossBackward0>)
# 61 tensor(3.1836, grad_fn=<NllLossBackward0>)
# 62 tensor(3.2794, grad_fn=<NllLossBackward0>)
# 63 tensor(3.1499, grad_fn=<NllLossBackward0>)
# 64 tensor(3.1725, grad_fn=<NllLossBackward0>)
# 65 tensor(3.2397, grad_fn=<NllLossBackward0>)
# 66 tensor(3.2886, grad_fn=<NllLossBackward0>)
# 67 tensor(3.1417, grad_fn=<NllLossBackward0>)
# 68 tensor(3.1024, grad_fn=<NllLossBackward0>)
# 69 tensor(3.2593, grad_fn=<NllLossBackward0>)
# 70 tensor(3.1450, grad_fn=<NllLossBackward0>)
# 71 tensor(3.0598, grad_fn=<NllLossBackward0>)
# 72 tensor(3.2061, grad_fn=<NllLossBackward0>)
# 73 tensor(3.1043, grad_fn=<NllLossBackward0>)
# 74 tensor(3.1217, grad_fn=<NllLossBackward0>)
# 75 tensor(3.1519, grad_fn=<NllLossBackward0>)
# 76 tensor(3.0856, grad_fn=<NllLossBackward0>)
# 77 tensor(3.1804, grad_fn=<NllLossBackward0>)
# 78 tensor(3.1669, grad_fn=<NllLossBackward0>)
# 79 tensor(3.1699, grad_fn=<NllLossBackward0>)
# 80 tensor(3.0219, grad_fn=<NllLossBackward0>)
# 81 tensor(3.0927, grad_fn=<NllLossBackward0>)
# 82 tensor(3.0621, grad_fn=<NllLossBackward0>)
# 83 tensor(3.1536, grad_fn=<NllLossBackward0>)
# 84 tensor(3.0428, grad_fn=<NllLossBackward0>)
# 85 tensor(3.1530, grad_fn=<NllLossBackward0>)
# 86 tensor(3.0504, grad_fn=<NllLossBackward0>)
# 87 tensor(3.0376, grad_fn=<NllLossBackward0>)
# 88 tensor(3.0867, grad_fn=<NllLossBackward0>)
# 89 tensor(3.0946, grad_fn=<NllLossBackward0>)
# 90 tensor(2.9916, grad_fn=<NllLossBackward0>)
# 91 tensor(3.0956, grad_fn=<NllLossBackward0>)
# 92 tensor(2.9529, grad_fn=<NllLossBackward0>)
# 93 tensor(2.9838, grad_fn=<NllLossBackward0>)
# 94 tensor(3.0175, grad_fn=<NllLossBackward0>)
# 95 tensor(3.0242, grad_fn=<NllLossBackward0>)
# 96 tensor(2.9554, grad_fn=<NllLossBackward0>)
# 97 tensor(3.1261, grad_fn=<NllLossBackward0>)
# 98 tensor(3.0942, grad_fn=<NllLossBackward0>)
# 99 tensor(2.9625, grad_fn=<NllLossBackward0>)
# 100 tensor(2.9421, grad_fn=<NllLossBackward0>)
# 101 tensor(2.9203, grad_fn=<NllLossBackward0>)
# 102 tensor(2.9538, grad_fn=<NllLossBackward0>)
# 103 tensor(2.8898, grad_fn=<NllLossBackward0>)
# 104 tensor(2.9957, grad_fn=<NllLossBackward0>)
# 105 tensor(3.0172, grad_fn=<NllLossBackward0>)
# 106 tensor(2.8988, grad_fn=<NllLossBackward0>)
# 107 tensor(2.8675, grad_fn=<NllLossBackward0>)
# 108 tensor(2.9989, grad_fn=<NllLossBackward0>)
# 109 tensor(2.9336, grad_fn=<NllLossBackward0>)
# 110 tensor(2.9536, grad_fn=<NllLossBackward0>)
# 111 tensor(2.9126, grad_fn=<NllLossBackward0>)
# 112 tensor(2.9060, grad_fn=<NllLossBackward0>)
# 113 tensor(2.8515, grad_fn=<NllLossBackward0>)
# 114 tensor(2.9096, grad_fn=<NllLossBackward0>)
# 115 tensor(2.9151, grad_fn=<NllLossBackward0>)
# 116 tensor(2.8562, grad_fn=<NllLossBackward0>)
# 117 tensor(3.0041, grad_fn=<NllLossBackward0>)
# 118 tensor(2.8665, grad_fn=<NllLossBackward0>)
# 119 tensor(2.9161, grad_fn=<NllLossBackward0>)
# 120 tensor(2.8528, grad_fn=<NllLossBackward0>)
# 121 tensor(2.8776, grad_fn=<NllLossBackward0>)
# 122 tensor(2.8701, grad_fn=<NllLossBackward0>)
# 123 tensor(2.8922, grad_fn=<NllLossBackward0>)
# 124 tensor(2.8615, grad_fn=<NllLossBackward0>)
# 125 tensor(2.8875, grad_fn=<NllLossBackward0>)
# 126 tensor(2.8933, grad_fn=<NllLossBackward0>)
# 127 tensor(2.8358, grad_fn=<NllLossBackward0>)
# 128 tensor(2.8809, grad_fn=<NllLossBackward0>)
# 129 tensor(2.8323, grad_fn=<NllLossBackward0>)
# 130 tensor(2.8787, grad_fn=<NllLossBackward0>)
# 131 tensor(2.9052, grad_fn=<NllLossBackward0>)
# 132 tensor(2.8474, grad_fn=<NllLossBackward0>)
# 133 tensor(2.8806, grad_fn=<NllLossBackward0>)
# 134 tensor(2.9181, grad_fn=<NllLossBackward0>)
# 135 tensor(2.8136, grad_fn=<NllLossBackward0>)
# 136 tensor(2.7267, grad_fn=<NllLossBackward0>)
# 137 tensor(2.7739, grad_fn=<NllLossBackward0>)
# 138 tensor(2.8138, grad_fn=<NllLossBackward0>)
# 139 tensor(2.8106, grad_fn=<NllLossBackward0>)
# 140 tensor(2.8062, grad_fn=<NllLossBackward0>)
# 141 tensor(2.8283, grad_fn=<NllLossBackward0>)
# 142 tensor(2.7709, grad_fn=<NllLossBackward0>)
# 143 tensor(2.7714, grad_fn=<NllLossBackward0>)
# 144 tensor(2.8626, grad_fn=<NllLossBackward0>)
# 145 tensor(2.8517, grad_fn=<NllLossBackward0>)
# 146 tensor(2.8370, grad_fn=<NllLossBackward0>)
# 147 tensor(2.8433, grad_fn=<NllLossBackward0>)
# 148 tensor(2.7177, grad_fn=<NllLossBackward0>)
# 149 tensor(2.7700, grad_fn=<NllLossBackward0>)
# 150 tensor(2.7137, grad_fn=<NllLossBackward0>)
# 151 tensor(2.8121, grad_fn=<NllLossBackward0>)
# 152 tensor(2.7926, grad_fn=<NllLossBackward0>)
# 153 tensor(2.7442, grad_fn=<NllLossBackward0>)
# 154 tensor(2.7692, grad_fn=<NllLossBackward0>)
# 155 tensor(2.7256, grad_fn=<NllLossBackward0>)
# 156 tensor(2.7798, grad_fn=<NllLossBackward0>)
# 157 tensor(2.8800, grad_fn=<NllLossBackward0>)
# 158 tensor(2.8017, grad_fn=<NllLossBackward0>)
# 159 tensor(2.7229, grad_fn=<NllLossBackward0>)
# 160 tensor(2.6357, grad_fn=<NllLossBackward0>)
# 161 tensor(2.7301, grad_fn=<NllLossBackward0>)
# 162 tensor(2.7401, grad_fn=<NllLossBackward0>)
# 163 tensor(2.7287, grad_fn=<NllLossBackward0>)
# 164 tensor(2.6757, grad_fn=<NllLossBackward0>)
# 165 tensor(2.7419, grad_fn=<NllLossBackward0>)
# 166 tensor(2.7058, grad_fn=<NllLossBackward0>)
# 167 tensor(2.7853, grad_fn=<NllLossBackward0>)
# 168 tensor(2.7348, grad_fn=<NllLossBackward0>)
# 169 tensor(2.7851, grad_fn=<NllLossBackward0>)
# 170 tensor(2.7715, grad_fn=<NllLossBackward0>)
# 171 tensor(2.7372, grad_fn=<NllLossBackward0>)
# 172 tensor(2.7085, grad_fn=<NllLossBackward0>)
# 173 tensor(2.7627, grad_fn=<NllLossBackward0>)
# 174 tensor(2.7687, grad_fn=<NllLossBackward0>)
# 175 tensor(2.7364, grad_fn=<NllLossBackward0>)
# 176 tensor(2.6849, grad_fn=<NllLossBackward0>)
# 177 tensor(2.7227, grad_fn=<NllLossBackward0>)
# 178 tensor(2.7465, grad_fn=<NllLossBackward0>)
# 179 tensor(2.6989, grad_fn=<NllLossBackward0>)
# 180 tensor(2.6468, grad_fn=<NllLossBackward0>)
# 181 tensor(2.6340, grad_fn=<NllLossBackward0>)
# 182 tensor(2.6710, grad_fn=<NllLossBackward0>)
# 183 tensor(2.7481, grad_fn=<NllLossBackward0>)
# 184 tensor(2.7096, grad_fn=<NllLossBackward0>)
# 185 tensor(2.7592, grad_fn=<NllLossBackward0>)
# 186 tensor(2.6894, grad_fn=<NllLossBackward0>)
# 187 tensor(2.7619, grad_fn=<NllLossBackward0>)
# 188 tensor(2.6031, grad_fn=<NllLossBackward0>)
# 189 tensor(2.6971, grad_fn=<NllLossBackward0>)
# 190 tensor(2.5778, grad_fn=<NllLossBackward0>)
# 191 tensor(2.5972, grad_fn=<NllLossBackward0>)
# 192 tensor(2.6610, grad_fn=<NllLossBackward0>)
# 193 tensor(2.6823, grad_fn=<NllLossBackward0>)
# 194 tensor(2.7147, grad_fn=<NllLossBackward0>)
# 195 tensor(2.6438, grad_fn=<NllLossBackward0>)
# 196 tensor(2.6188, grad_fn=<NllLossBackward0>)
# 197 tensor(2.7201, grad_fn=<NllLossBackward0>)
# 198 tensor(2.6532, grad_fn=<NllLossBackward0>)
# 199 tensor(2.6871, grad_fn=<NllLossBackward0>)
# 200 tensor(2.6272, grad_fn=<NllLossBackward0>)
# 201 tensor(2.6290, grad_fn=<NllLossBackward0>)
# 202 tensor(2.6156, grad_fn=<NllLossBackward0>)
# 203 tensor(2.6392, grad_fn=<NllLossBackward0>)
# 204 tensor(2.6070, grad_fn=<NllLossBackward0>)
# 205 tensor(2.5944, grad_fn=<NllLossBackward0>)
# 206 tensor(2.6665, grad_fn=<NllLossBackward0>)
# 207 tensor(2.4977, grad_fn=<NllLossBackward0>)
# 208 tensor(2.6864, grad_fn=<NllLossBackward0>)
# 209 tensor(2.5712, grad_fn=<NllLossBackward0>)
# 210 tensor(2.5627, grad_fn=<NllLossBackward0>)
# 211 tensor(2.6336, grad_fn=<NllLossBackward0>)
# 212 tensor(2.6300, grad_fn=<NllLossBackward0>)
# 213 tensor(2.6332, grad_fn=<NllLossBackward0>)
# 214 tensor(2.6721, grad_fn=<NllLossBackward0>)
# 215 tensor(2.7494, grad_fn=<NllLossBackward0>)
# 216 tensor(2.6321, grad_fn=<NllLossBackward0>)
# 217 tensor(2.6258, grad_fn=<NllLossBackward0>)
# 218 tensor(2.6971, grad_fn=<NllLossBackward0>)
# 219 tensor(2.6514, grad_fn=<NllLossBackward0>)
# 220 tensor(2.6614, grad_fn=<NllLossBackward0>)
# 221 tensor(2.6436, grad_fn=<NllLossBackward0>)
# 222 tensor(2.6305, grad_fn=<NllLossBackward0>)
# 223 tensor(2.6378, grad_fn=<NllLossBackward0>)
# 224 tensor(2.5551, grad_fn=<NllLossBackward0>)
# 225 tensor(2.6648, grad_fn=<NllLossBackward0>)
# 226 tensor(2.5740, grad_fn=<NllLossBackward0>)
# 227 tensor(2.6225, grad_fn=<NllLossBackward0>)
# 228 tensor(2.6020, grad_fn=<NllLossBackward0>)
# 229 tensor(2.6216, grad_fn=<NllLossBackward0>)
# 230 tensor(2.5231, grad_fn=<NllLossBackward0>)
# 231 tensor(2.5787, grad_fn=<NllLossBackward0>)
# 232 tensor(2.5887, grad_fn=<NllLossBackward0>)
# 233 tensor(2.6551, grad_fn=<NllLossBackward0>)
# 234 tensor(2.6125, grad_fn=<NllLossBackward0>)
# 235 tensor(2.6333, grad_fn=<NllLossBackward0>)
# 236 tensor(2.5535, grad_fn=<NllLossBackward0>)
# 237 tensor(2.5844, grad_fn=<NllLossBackward0>)
# 238 tensor(2.5761, grad_fn=<NllLossBackward0>)
# 239 tensor(2.5721, grad_fn=<NllLossBackward0>)
# 240 tensor(2.5886, grad_fn=<NllLossBackward0>)
# 241 tensor(2.6369, grad_fn=<NllLossBackward0>)
# 242 tensor(2.6098, grad_fn=<NllLossBackward0>)
# 243 tensor(2.6230, grad_fn=<NllLossBackward0>)
# 244 tensor(2.5844, grad_fn=<NllLossBackward0>)
# 245 tensor(2.5898, grad_fn=<NllLossBackward0>)
# 246 tensor(2.6315, grad_fn=<NllLossBackward0>)
# 247 tensor(2.5855, grad_fn=<NllLossBackward0>)
# 248 tensor(2.5603, grad_fn=<NllLossBackward0>)
# 249 tensor(2.5996, grad_fn=<NllLossBackward0>)
# 250 tensor(2.6115, grad_fn=<NllLossBackward0>)
# 251 tensor(2.6097, grad_fn=<NllLossBackward0>)
# 252 tensor(2.5622, grad_fn=<NllLossBackward0>)
# 253 tensor(2.5706, grad_fn=<NllLossBackward0>)
# 254 tensor(2.5984, grad_fn=<NllLossBackward0>)
# 255 tensor(2.5759, grad_fn=<NllLossBackward0>)
# 256 tensor(2.6271, grad_fn=<NllLossBackward0>)
# 257 tensor(2.5845, grad_fn=<NllLossBackward0>)
# 258 tensor(2.5751, grad_fn=<NllLossBackward0>)
# 259 tensor(2.5321, grad_fn=<NllLossBackward0>)
# 260 tensor(2.5272, grad_fn=<NllLossBackward0>)
# 261 tensor(2.6225, grad_fn=<NllLossBackward0>)
# 262 tensor(2.5966, grad_fn=<NllLossBackward0>)
# 263 tensor(2.5942, grad_fn=<NllLossBackward0>)
# 264 tensor(2.5652, grad_fn=<NllLossBackward0>)
# 265 tensor(2.5212, grad_fn=<NllLossBackward0>)
# 266 tensor(2.5947, grad_fn=<NllLossBackward0>)
# 267 tensor(2.5888, grad_fn=<NllLossBackward0>)
# 268 tensor(2.5868, grad_fn=<NllLossBackward0>)
# 269 tensor(2.4940, grad_fn=<NllLossBackward0>)
# 270 tensor(2.6184, grad_fn=<NllLossBackward0>)
# 271 tensor(2.5218, grad_fn=<NllLossBackward0>)
# 272 tensor(2.5775, grad_fn=<NllLossBackward0>)
# 273 tensor(2.4888, grad_fn=<NllLossBackward0>)
# 274 tensor(2.5352, grad_fn=<NllLossBackward0>)
# 275 tensor(2.5543, grad_fn=<NllLossBackward0>)
# 276 tensor(2.5862, grad_fn=<NllLossBackward0>)
# 277 tensor(2.5208, grad_fn=<NllLossBackward0>)
# 278 tensor(2.5677, grad_fn=<NllLossBackward0>)
# 279 tensor(2.5329, grad_fn=<NllLossBackward0>)
# 280 tensor(2.6197, grad_fn=<NllLossBackward0>)
# 281 tensor(2.5404, grad_fn=<NllLossBackward0>)
# 282 tensor(2.5843, grad_fn=<NllLossBackward0>)
# 283 tensor(2.6609, grad_fn=<NllLossBackward0>)
# 284 tensor(2.5965, grad_fn=<NllLossBackward0>)
# 285 tensor(2.5244, grad_fn=<NllLossBackward0>)
# 286 tensor(2.5427, grad_fn=<NllLossBackward0>)
# 287 tensor(2.5871, grad_fn=<NllLossBackward0>)
# 288 tensor(2.5542, grad_fn=<NllLossBackward0>)
# 289 tensor(2.5439, grad_fn=<NllLossBackward0>)
# 290 tensor(2.5533, grad_fn=<NllLossBackward0>)
# 291 tensor(2.5125, grad_fn=<NllLossBackward0>)
# 292 tensor(2.5435, grad_fn=<NllLossBackward0>)
# 293 tensor(2.5903, grad_fn=<NllLossBackward0>)
# 294 tensor(2.5396, grad_fn=<NllLossBackward0>)
# 295 tensor(2.5227, grad_fn=<NllLossBackward0>)
# 296 tensor(2.5581, grad_fn=<NllLossBackward0>)
# 297 tensor(2.5683, grad_fn=<NllLossBackward0>)
# 298 tensor(2.5948, grad_fn=<NllLossBackward0>)
# 299 tensor(2.6325, grad_fn=<NllLossBackward0>)
# 300 tensor(2.5747, grad_fn=<NllLossBackward0>)
# 301 tensor(2.5351, grad_fn=<NllLossBackward0>)
# 302 tensor(2.5222, grad_fn=<NllLossBackward0>)
# 303 tensor(2.5456, grad_fn=<NllLossBackward0>)
# 304 tensor(2.4791, grad_fn=<NllLossBackward0>)
# 305 tensor(2.5525, grad_fn=<NllLossBackward0>)
# 306 tensor(2.5501, grad_fn=<NllLossBackward0>)
# 307 tensor(2.5196, grad_fn=<NllLossBackward0>)
# 308 tensor(2.5131, grad_fn=<NllLossBackward0>)
# 309 tensor(2.5350, grad_fn=<NllLossBackward0>)
# 310 tensor(2.5579, grad_fn=<NllLossBackward0>)
# 311 tensor(2.5293, grad_fn=<NllLossBackward0>)
# 312 tensor(2.5724, grad_fn=<NllLossBackward0>)
# 313 tensor(2.5081, grad_fn=<NllLossBackward0>)
# 314 tensor(2.5116, grad_fn=<NllLossBackward0>)
# 315 tensor(2.5066, grad_fn=<NllLossBackward0>)
# 316 tensor(2.5445, grad_fn=<NllLossBackward0>)
# 317 tensor(2.5641, grad_fn=<NllLossBackward0>)
# 318 tensor(2.5083, grad_fn=<NllLossBackward0>)
# 319 tensor(2.5237, grad_fn=<NllLossBackward0>)
# 320 tensor(2.4842, grad_fn=<NllLossBackward0>)
# 321 tensor(2.4800, grad_fn=<NllLossBackward0>)
# 322 tensor(2.4526, grad_fn=<NllLossBackward0>)
# 323 tensor(2.5490, grad_fn=<NllLossBackward0>)
# 324 tensor(2.4890, grad_fn=<NllLossBackward0>)
# 325 tensor(2.5025, grad_fn=<NllLossBackward0>)
# 326 tensor(2.5645, grad_fn=<NllLossBackward0>)
# 327 tensor(2.5198, grad_fn=<NllLossBackward0>)
# 328 tensor(2.5512, grad_fn=<NllLossBackward0>)
# 329 tensor(2.5592, grad_fn=<NllLossBackward0>)
# 330 tensor(2.5831, grad_fn=<NllLossBackward0>)
# 331 tensor(2.5143, grad_fn=<NllLossBackward0>)
# 332 tensor(2.4967, grad_fn=<NllLossBackward0>)
# 333 tensor(2.4689, grad_fn=<NllLossBackward0>)
# 334 tensor(2.4906, grad_fn=<NllLossBackward0>)
# 335 tensor(2.4667, grad_fn=<NllLossBackward0>)
# 336 tensor(2.6011, grad_fn=<NllLossBackward0>)
# 337 tensor(2.4168, grad_fn=<NllLossBackward0>)
# 338 tensor(2.4485, grad_fn=<NllLossBackward0>)
# 339 tensor(2.5131, grad_fn=<NllLossBackward0>)
# 340 tensor(2.4767, grad_fn=<NllLossBackward0>)
# 341 tensor(2.4550, grad_fn=<NllLossBackward0>)
# 342 tensor(2.5522, grad_fn=<NllLossBackward0>)
# 343 tensor(2.4807, grad_fn=<NllLossBackward0>)
# 344 tensor(2.5216, grad_fn=<NllLossBackward0>)
# 345 tensor(2.4570, grad_fn=<NllLossBackward0>)
# 346 tensor(2.4741, grad_fn=<NllLossBackward0>)
# 347 tensor(2.4715, grad_fn=<NllLossBackward0>)
# 348 tensor(2.5331, grad_fn=<NllLossBackward0>)
# 349 tensor(2.4737, grad_fn=<NllLossBackward0>)
# 350 tensor(2.4928, grad_fn=<NllLossBackward0>)
# 351 tensor(2.4318, grad_fn=<NllLossBackward0>)
# 352 tensor(2.4695, grad_fn=<NllLossBackward0>)
# 353 tensor(2.4498, grad_fn=<NllLossBackward0>)
# 354 tensor(2.5027, grad_fn=<NllLossBackward0>)
# 355 tensor(2.5190, grad_fn=<NllLossBackward0>)
# 356 tensor(2.4504, grad_fn=<NllLossBackward0>)
# 357 tensor(2.4261, grad_fn=<NllLossBackward0>)
# 358 tensor(2.3303, grad_fn=<NllLossBackward0>)
# 359 tensor(2.5260, grad_fn=<NllLossBackward0>)
# 360 tensor(2.4883, grad_fn=<NllLossBackward0>)
# 361 tensor(2.5700, grad_fn=<NllLossBackward0>)
# 362 tensor(2.5064, grad_fn=<NllLossBackward0>)
# 363 tensor(2.5460, grad_fn=<NllLossBackward0>)
# 364 tensor(2.4070, grad_fn=<NllLossBackward0>)
# 365 tensor(2.4421, grad_fn=<NllLossBackward0>)
# 366 tensor(2.4339, grad_fn=<NllLossBackward0>)
# 367 tensor(2.4569, grad_fn=<NllLossBackward0>)
# 368 tensor(2.4465, grad_fn=<NllLossBackward0>)
# 369 tensor(2.5049, grad_fn=<NllLossBackward0>)
# 370 tensor(2.5422, grad_fn=<NllLossBackward0>)
# 371 tensor(2.4430, grad_fn=<NllLossBackward0>)
# 372 tensor(2.4486, grad_fn=<NllLossBackward0>)
# 373 tensor(2.4156, grad_fn=<NllLossBackward0>)
# 374 tensor(2.5115, grad_fn=<NllLossBackward0>)
# 375 tensor(2.4496, grad_fn=<NllLossBackward0>)
# 376 tensor(2.5469, grad_fn=<NllLossBackward0>)
# 377 tensor(2.5119, grad_fn=<NllLossBackward0>)
# 378 tensor(2.4601, grad_fn=<NllLossBackward0>)
# 379 tensor(2.4672, grad_fn=<NllLossBackward0>)
# 380 tensor(2.3927, grad_fn=<NllLossBackward0>)
# 381 tensor(2.4801, grad_fn=<NllLossBackward0>)
# 382 tensor(2.5346, grad_fn=<NllLossBackward0>)
# 383 tensor(2.4524, grad_fn=<NllLossBackward0>)
# 384 tensor(2.4062, grad_fn=<NllLossBackward0>)
# 385 tensor(2.4373, grad_fn=<NllLossBackward0>)
# 386 tensor(2.5154, grad_fn=<NllLossBackward0>)
# 387 tensor(2.4130, grad_fn=<NllLossBackward0>)
# 388 tensor(2.4535, grad_fn=<NllLossBackward0>)
# 389 tensor(2.4614, grad_fn=<NllLossBackward0>)
# 390 tensor(2.4923, grad_fn=<NllLossBackward0>)
# 391 tensor(2.4719, grad_fn=<NllLossBackward0>)
# 392 tensor(2.5403, grad_fn=<NllLossBackward0>)
# 393 tensor(2.4222, grad_fn=<NllLossBackward0>)
# 394 tensor(2.5044, grad_fn=<NllLossBackward0>)
# 395 tensor(2.5043, grad_fn=<NllLossBackward0>)
# 396 tensor(2.4590, grad_fn=<NllLossBackward0>)
# 397 tensor(2.4923, grad_fn=<NllLossBackward0>)
# 398 tensor(2.4045, grad_fn=<NllLossBackward0>)
# 399 tensor(2.4676, grad_fn=<NllLossBackward0>)
# 400 tensor(2.4331, grad_fn=<NllLossBackward0>)
# 401 tensor(2.4624, grad_fn=<NllLossBackward0>)
# 402 tensor(2.4549, grad_fn=<NllLossBackward0>)
# 403 tensor(2.4775, grad_fn=<NllLossBackward0>)
# 404 tensor(2.4121, grad_fn=<NllLossBackward0>)
# 405 tensor(2.4391, grad_fn=<NllLossBackward0>)
# 406 tensor(2.4592, grad_fn=<NllLossBackward0>)
# 407 tensor(2.3809, grad_fn=<NllLossBackward0>)
# 408 tensor(2.3530, grad_fn=<NllLossBackward0>)
# 409 tensor(2.4798, grad_fn=<NllLossBackward0>)
# 410 tensor(2.5035, grad_fn=<NllLossBackward0>)
# 411 tensor(2.4424, grad_fn=<NllLossBackward0>)
# 412 tensor(2.4696, grad_fn=<NllLossBackward0>)
# 413 tensor(2.4634, grad_fn=<NllLossBackward0>)
# 414 tensor(2.5001, grad_fn=<NllLossBackward0>)
# 415 tensor(2.4467, grad_fn=<NllLossBackward0>)
# 416 tensor(2.4410, grad_fn=<NllLossBackward0>)
# 417 tensor(2.4924, grad_fn=<NllLossBackward0>)
# 418 tensor(2.4137, grad_fn=<NllLossBackward0>)
# 419 tensor(2.4583, grad_fn=<NllLossBackward0>)
# 420 tensor(2.4212, grad_fn=<NllLossBackward0>)
# 421 tensor(2.4290, grad_fn=<NllLossBackward0>)
# 422 tensor(2.4559, grad_fn=<NllLossBackward0>)
# 423 tensor(2.4670, grad_fn=<NllLossBackward0>)
# 424 tensor(2.4326, grad_fn=<NllLossBackward0>)
# 425 tensor(2.3972, grad_fn=<NllLossBackward0>)
# 426 tensor(2.4701, grad_fn=<NllLossBackward0>)
# 427 tensor(2.4139, grad_fn=<NllLossBackward0>)
# 428 tensor(2.4080, grad_fn=<NllLossBackward0>)
# 429 tensor(2.3682, grad_fn=<NllLossBackward0>)
# 430 tensor(2.4014, grad_fn=<NllLossBackward0>)
# 431 tensor(2.3993, grad_fn=<NllLossBackward0>)
# 432 tensor(2.4751, grad_fn=<NllLossBackward0>)
# 433 tensor(2.4255, grad_fn=<NllLossBackward0>)
# 434 tensor(2.4317, grad_fn=<NllLossBackward0>)
# 435 tensor(2.3812, grad_fn=<NllLossBackward0>)
# 436 tensor(2.4236, grad_fn=<NllLossBackward0>)
# 437 tensor(2.4680, grad_fn=<NllLossBackward0>)
# 438 tensor(2.4444, grad_fn=<NllLossBackward0>)
# 439 tensor(2.4872, grad_fn=<NllLossBackward0>)
# 440 tensor(2.4222, grad_fn=<NllLossBackward0>)
# 441 tensor(2.4824, grad_fn=<NllLossBackward0>)
# 442 tensor(2.3917, grad_fn=<NllLossBackward0>)
# 443 tensor(2.4155, grad_fn=<NllLossBackward0>)
# 444 tensor(2.4814, grad_fn=<NllLossBackward0>)
# 445 tensor(2.4754, grad_fn=<NllLossBackward0>)
# 446 tensor(2.4108, grad_fn=<NllLossBackward0>)
# 447 tensor(2.4399, grad_fn=<NllLossBackward0>)
# 448 tensor(2.3889, grad_fn=<NllLossBackward0>)
# 449 tensor(2.4589, grad_fn=<NllLossBackward0>)
# 450 tensor(2.4132, grad_fn=<NllLossBackward0>)
# 451 tensor(2.3924, grad_fn=<NllLossBackward0>)
# 452 tensor(2.4510, grad_fn=<NllLossBackward0>)
# 453 tensor(2.4119, grad_fn=<NllLossBackward0>)
# 454 tensor(2.4110, grad_fn=<NllLossBackward0>)
# 455 tensor(2.4783, grad_fn=<NllLossBackward0>)
# 456 tensor(2.4479, grad_fn=<NllLossBackward0>)
# 457 tensor(2.4589, grad_fn=<NllLossBackward0>)
# 458 tensor(2.4453, grad_fn=<NllLossBackward0>)
# 459 tensor(2.5313, grad_fn=<NllLossBackward0>)
# 460 tensor(2.4555, grad_fn=<NllLossBackward0>)
# 461 tensor(2.3692, grad_fn=<NllLossBackward0>)
# 462 tensor(2.3933, grad_fn=<NllLossBackward0>)
# 463 tensor(2.4283, grad_fn=<NllLossBackward0>)
# 464 tensor(2.4637, grad_fn=<NllLossBackward0>)
# 465 tensor(2.4642, grad_fn=<NllLossBackward0>)
# 466 tensor(2.4599, grad_fn=<NllLossBackward0>)
# 467 tensor(2.4424, grad_fn=<NllLossBackward0>)
# 468 tensor(2.5086, grad_fn=<NllLossBackward0>)
# 469 tensor(2.4663, grad_fn=<NllLossBackward0>)
# 470 tensor(2.3645, grad_fn=<NllLossBackward0>)
# 471 tensor(2.3813, grad_fn=<NllLossBackward0>)
# 472 tensor(2.3688, grad_fn=<NllLossBackward0>)
# 473 tensor(2.4015, grad_fn=<NllLossBackward0>)
# 474 tensor(2.4024, grad_fn=<NllLossBackward0>)
# 475 tensor(2.3961, grad_fn=<NllLossBackward0>)
# 476 tensor(2.4562, grad_fn=<NllLossBackward0>)
# 477 tensor(2.4579, grad_fn=<NllLossBackward0>)
# 478 tensor(2.4701, grad_fn=<NllLossBackward0>)
# 479 tensor(2.4474, grad_fn=<NllLossBackward0>)
# 480 tensor(2.3956, grad_fn=<NllLossBackward0>)
# 481 tensor(2.3651, grad_fn=<NllLossBackward0>)
# 482 tensor(2.4554, grad_fn=<NllLossBackward0>)
# 483 tensor(2.4170, grad_fn=<NllLossBackward0>)
# 484 tensor(2.4313, grad_fn=<NllLossBackward0>)
# 485 tensor(2.4482, grad_fn=<NllLossBackward0>)
# 486 tensor(2.4786, grad_fn=<NllLossBackward0>)
# 487 tensor(2.4074, grad_fn=<NllLossBackward0>)
# 488 tensor(2.3957, grad_fn=<NllLossBackward0>)
# 489 tensor(2.4210, grad_fn=<NllLossBackward0>)
# 490 tensor(2.4901, grad_fn=<NllLossBackward0>)
# 491 tensor(2.4090, grad_fn=<NllLossBackward0>)
# 492 tensor(2.4238, grad_fn=<NllLossBackward0>)
# 493 tensor(2.3659, grad_fn=<NllLossBackward0>)
# 494 tensor(2.4141, grad_fn=<NllLossBackward0>)
# 495 tensor(2.4607, grad_fn=<NllLossBackward0>)
# 496 tensor(2.3448, grad_fn=<NllLossBackward0>)
# 497 tensor(2.3864, grad_fn=<NllLossBackward0>)
# 498 tensor(2.4226, grad_fn=<NllLossBackward0>)
# 499 tensor(2.4458, grad_fn=<NllLossBackward0>)
# 500 tensor(2.4012, grad_fn=<NllLossBackward0>)
# 501 tensor(2.3947, grad_fn=<NllLossBackward0>)
# 502 tensor(2.2994, grad_fn=<NllLossBackward0>)
# 503 tensor(2.3954, grad_fn=<NllLossBackward0>)
# 504 tensor(2.3906, grad_fn=<NllLossBackward0>)
# 505 tensor(2.3785, grad_fn=<NllLossBackward0>)
# 506 tensor(2.3319, grad_fn=<NllLossBackward0>)
# 507 tensor(2.4056, grad_fn=<NllLossBackward0>)
# 508 tensor(2.3631, grad_fn=<NllLossBackward0>)
# 509 tensor(2.3856, grad_fn=<NllLossBackward0>)
# 510 tensor(2.3810, grad_fn=<NllLossBackward0>)
# 511 tensor(2.3925, grad_fn=<NllLossBackward0>)
# 512 tensor(2.3749, grad_fn=<NllLossBackward0>)
# 513 tensor(2.3854, grad_fn=<NllLossBackward0>)
# 514 tensor(2.3217, grad_fn=<NllLossBackward0>)
# 515 tensor(2.2891, grad_fn=<NllLossBackward0>)
# 516 tensor(2.4494, grad_fn=<NllLossBackward0>)
# 517 tensor(2.4142, grad_fn=<NllLossBackward0>)
# 518 tensor(2.3421, grad_fn=<NllLossBackward0>)
# 519 tensor(2.3704, grad_fn=<NllLossBackward0>)
# 520 tensor(2.3822, grad_fn=<NllLossBackward0>)
# 521 tensor(2.4561, grad_fn=<NllLossBackward0>)
# 522 tensor(2.3787, grad_fn=<NllLossBackward0>)
# 523 tensor(2.4611, grad_fn=<NllLossBackward0>)
# 524 tensor(2.3056, grad_fn=<NllLossBackward0>)
# 525 tensor(2.4301, grad_fn=<NllLossBackward0>)
# 526 tensor(2.3753, grad_fn=<NllLossBackward0>)
# 527 tensor(2.3818, grad_fn=<NllLossBackward0>)
# 528 tensor(2.4059, grad_fn=<NllLossBackward0>)
# 529 tensor(2.3807, grad_fn=<NllLossBackward0>)
# 530 tensor(2.3971, grad_fn=<NllLossBackward0>)
# 531 tensor(2.3981, grad_fn=<NllLossBackward0>)
# 532 tensor(2.3931, grad_fn=<NllLossBackward0>)
# 533 tensor(2.4712, grad_fn=<NllLossBackward0>)
# 534 tensor(2.4356, grad_fn=<NllLossBackward0>)
# 535 tensor(2.4200, grad_fn=<NllLossBackward0>)
# 536 tensor(2.3211, grad_fn=<NllLossBackward0>)
# 537 tensor(2.3660, grad_fn=<NllLossBackward0>)
# 538 tensor(2.3846, grad_fn=<NllLossBackward0>)
# 539 tensor(2.4209, grad_fn=<NllLossBackward0>)
# 540 tensor(2.4127, grad_fn=<NllLossBackward0>)
# 541 tensor(2.2782, grad_fn=<NllLossBackward0>)
# 542 tensor(2.3025, grad_fn=<NllLossBackward0>)
# 543 tensor(2.3583, grad_fn=<NllLossBackward0>)
# 544 tensor(2.4323, grad_fn=<NllLossBackward0>)
# 545 tensor(2.4099, grad_fn=<NllLossBackward0>)
# 546 tensor(2.3852, grad_fn=<NllLossBackward0>)
# 547 tensor(2.3382, grad_fn=<NllLossBackward0>)
# 548 tensor(2.4413, grad_fn=<NllLossBackward0>)
# 549 tensor(2.4050, grad_fn=<NllLossBackward0>)
# 550 tensor(2.4218, grad_fn=<NllLossBackward0>)
# 551 tensor(2.3237, grad_fn=<NllLossBackward0>)
# 552 tensor(2.3842, grad_fn=<NllLossBackward0>)
# 553 tensor(2.4095, grad_fn=<NllLossBackward0>)
# 554 tensor(2.4255, grad_fn=<NllLossBackward0>)
# 555 tensor(2.3956, grad_fn=<NllLossBackward0>)
# 556 tensor(2.4016, grad_fn=<NllLossBackward0>)
# 557 tensor(2.3772, grad_fn=<NllLossBackward0>)
# 558 tensor(2.4342, grad_fn=<NllLossBackward0>)
# 559 tensor(2.3810, grad_fn=<NllLossBackward0>)
# 560 tensor(2.3587, grad_fn=<NllLossBackward0>)
# 561 tensor(2.3788, grad_fn=<NllLossBackward0>)
# 562 tensor(2.3535, grad_fn=<NllLossBackward0>)
# 563 tensor(2.2528, grad_fn=<NllLossBackward0>)
# 564 tensor(2.3073, grad_fn=<NllLossBackward0>)
# 565 tensor(2.3888, grad_fn=<NllLossBackward0>)
# 566 tensor(2.3402, grad_fn=<NllLossBackward0>)
# 567 tensor(2.4385, grad_fn=<NllLossBackward0>)
# 568 tensor(2.3492, grad_fn=<NllLossBackward0>)
# 569 tensor(2.4793, grad_fn=<NllLossBackward0>)
# 570 tensor(2.3310, grad_fn=<NllLossBackward0>)
# 571 tensor(2.4509, grad_fn=<NllLossBackward0>)
# 572 tensor(2.4595, grad_fn=<NllLossBackward0>)
# 573 tensor(2.4119, grad_fn=<NllLossBackward0>)
# 574 tensor(2.3957, grad_fn=<NllLossBackward0>)
# 575 tensor(2.4472, grad_fn=<NllLossBackward0>)
# 576 tensor(2.3449, grad_fn=<NllLossBackward0>)
# 577 tensor(2.4055, grad_fn=<NllLossBackward0>)
# 578 tensor(2.3843, grad_fn=<NllLossBackward0>)
# 579 tensor(2.3826, grad_fn=<NllLossBackward0>)
# 580 tensor(2.4019, grad_fn=<NllLossBackward0>)
# 581 tensor(2.3140, grad_fn=<NllLossBackward0>)
# 582 tensor(2.4111, grad_fn=<NllLossBackward0>)
# 583 tensor(2.4461, grad_fn=<NllLossBackward0>)
# 584 tensor(2.3679, grad_fn=<NllLossBackward0>)
# 585 tensor(2.4024, grad_fn=<NllLossBackward0>)
# 586 tensor(2.4018, grad_fn=<NllLossBackward0>)
# 587 tensor(2.4306, grad_fn=<NllLossBackward0>)
# 588 tensor(2.3180, grad_fn=<NllLossBackward0>)
# 589 tensor(2.2713, grad_fn=<NllLossBackward0>)
# 590 tensor(2.3308, grad_fn=<NllLossBackward0>)
# 591 tensor(2.4063, grad_fn=<NllLossBackward0>)
# 592 tensor(2.3270, grad_fn=<NllLossBackward0>)
# 593 tensor(2.3307, grad_fn=<NllLossBackward0>)
# 594 tensor(2.2883, grad_fn=<NllLossBackward0>)
# 595 tensor(2.3897, grad_fn=<NllLossBackward0>)
# 596 tensor(2.3793, grad_fn=<NllLossBackward0>)
# 597 tensor(2.3173, grad_fn=<NllLossBackward0>)
# 598 tensor(2.3453, grad_fn=<NllLossBackward0>)
# 599 tensor(2.3059, grad_fn=<NllLossBackward0>)
# 600 tensor(2.3802, grad_fn=<NllLossBackward0>)
# 601 tensor(2.4041, grad_fn=<NllLossBackward0>)
# 602 tensor(2.3931, grad_fn=<NllLossBackward0>)
# 603 tensor(2.3678, grad_fn=<NllLossBackward0>)
# 604 tensor(2.3898, grad_fn=<NllLossBackward0>)
# 605 tensor(2.3475, grad_fn=<NllLossBackward0>)
# 606 tensor(2.3841, grad_fn=<NllLossBackward0>)
# 607 tensor(2.3877, grad_fn=<NllLossBackward0>)
# 608 tensor(2.3385, grad_fn=<NllLossBackward0>)
# 609 tensor(2.3280, grad_fn=<NllLossBackward0>)
# 610 tensor(2.3669, grad_fn=<NllLossBackward0>)
# 611 tensor(2.3249, grad_fn=<NllLossBackward0>)
# 612 tensor(2.3222, grad_fn=<NllLossBackward0>)
# 613 tensor(2.3208, grad_fn=<NllLossBackward0>)
# 614 tensor(2.4271, grad_fn=<NllLossBackward0>)
# 615 tensor(2.2907, grad_fn=<NllLossBackward0>)
# 616 tensor(2.3410, grad_fn=<NllLossBackward0>)
# 617 tensor(2.3755, grad_fn=<NllLossBackward0>)
# 618 tensor(2.3934, grad_fn=<NllLossBackward0>)
# 619 tensor(2.4126, grad_fn=<NllLossBackward0>)
# 620 tensor(2.2799, grad_fn=<NllLossBackward0>)
# 621 tensor(2.2704, grad_fn=<NllLossBackward0>)
# 622 tensor(2.3238, grad_fn=<NllLossBackward0>)
# 623 tensor(2.3009, grad_fn=<NllLossBackward0>)
# 624 tensor(2.2660, grad_fn=<NllLossBackward0>)
# 625 tensor(2.3562, grad_fn=<NllLossBackward0>)
# 626 tensor(2.3133, grad_fn=<NllLossBackward0>)
# 627 tensor(2.3575, grad_fn=<NllLossBackward0>)
# 628 tensor(2.3335, grad_fn=<NllLossBackward0>)
# 629 tensor(2.3416, grad_fn=<NllLossBackward0>)
# 630 tensor(2.3754, grad_fn=<NllLossBackward0>)
# 631 tensor(2.3537, grad_fn=<NllLossBackward0>)
# 632 tensor(2.2871, grad_fn=<NllLossBackward0>)
# 633 tensor(2.4167, grad_fn=<NllLossBackward0>)
# 634 tensor(2.3277, grad_fn=<NllLossBackward0>)
# 635 tensor(2.3145, grad_fn=<NllLossBackward0>)
# 636 tensor(2.3595, grad_fn=<NllLossBackward0>)
# 637 tensor(2.3301, grad_fn=<NllLossBackward0>)
# 638 tensor(2.3832, grad_fn=<NllLossBackward0>)
# 639 tensor(2.3384, grad_fn=<NllLossBackward0>)
# 640 tensor(2.3896, grad_fn=<NllLossBackward0>)
# 641 tensor(2.4001, grad_fn=<NllLossBackward0>)
# 642 tensor(2.3387, grad_fn=<NllLossBackward0>)
# 643 tensor(2.4138, grad_fn=<NllLossBackward0>)
# 644 tensor(2.3616, grad_fn=<NllLossBackward0>)
# 645 tensor(2.3311, grad_fn=<NllLossBackward0>)
# 646 tensor(2.3411, grad_fn=<NllLossBackward0>)
# 647 tensor(2.3495, grad_fn=<NllLossBackward0>)
# 648 tensor(2.3176, grad_fn=<NllLossBackward0>)
# 649 tensor(2.3695, grad_fn=<NllLossBackward0>)
# 650 tensor(2.3050, grad_fn=<NllLossBackward0>)
# 651 tensor(2.3943, grad_fn=<NllLossBackward0>)
# 652 tensor(2.2952, grad_fn=<NllLossBackward0>)
# 653 tensor(2.3931, grad_fn=<NllLossBackward0>)
# 654 tensor(2.3767, grad_fn=<NllLossBackward0>)
# 655 tensor(2.3331, grad_fn=<NllLossBackward0>)
# 656 tensor(2.3834, grad_fn=<NllLossBackward0>)
# 657 tensor(2.3473, grad_fn=<NllLossBackward0>)
# 658 tensor(2.4669, grad_fn=<NllLossBackward0>)
# 659 tensor(2.3569, grad_fn=<NllLossBackward0>)
# 660 tensor(2.3278, grad_fn=<NllLossBackward0>)
# 661 tensor(2.3929, grad_fn=<NllLossBackward0>)
# 662 tensor(2.3502, grad_fn=<NllLossBackward0>)
# 663 tensor(2.3758, grad_fn=<NllLossBackward0>)
# 664 tensor(2.3322, grad_fn=<NllLossBackward0>)
# 665 tensor(2.3270, grad_fn=<NllLossBackward0>)
# 666 tensor(2.4266, grad_fn=<NllLossBackward0>)
# 667 tensor(2.3913, grad_fn=<NllLossBackward0>)
# 668 tensor(2.4267, grad_fn=<NllLossBackward0>)
# 669 tensor(2.3107, grad_fn=<NllLossBackward0>)
# 670 tensor(2.3800, grad_fn=<NllLossBackward0>)
# 671 tensor(2.3736, grad_fn=<NllLossBackward0>)
# 672 tensor(2.3662, grad_fn=<NllLossBackward0>)
# 673 tensor(2.3283, grad_fn=<NllLossBackward0>)
# 674 tensor(2.4052, grad_fn=<NllLossBackward0>)
# 675 tensor(2.3107, grad_fn=<NllLossBackward0>)
# 676 tensor(2.3860, grad_fn=<NllLossBackward0>)
# 677 tensor(2.4033, grad_fn=<NllLossBackward0>)
# 678 tensor(2.3182, grad_fn=<NllLossBackward0>)
# 679 tensor(2.3422, grad_fn=<NllLossBackward0>)
# 680 tensor(2.4021, grad_fn=<NllLossBackward0>)
# 681 tensor(2.3049, grad_fn=<NllLossBackward0>)
# 682 tensor(2.3584, grad_fn=<NllLossBackward0>)
# 683 tensor(2.3311, grad_fn=<NllLossBackward0>)
# 684 tensor(2.3680, grad_fn=<NllLossBackward0>)
# 685 tensor(2.3086, grad_fn=<NllLossBackward0>)
# 686 tensor(2.2950, grad_fn=<NllLossBackward0>)
# 687 tensor(2.3899, grad_fn=<NllLossBackward0>)
# 688 tensor(2.3485, grad_fn=<NllLossBackward0>)
# 689 tensor(2.3707, grad_fn=<NllLossBackward0>)
# 690 tensor(2.2886, grad_fn=<NllLossBackward0>)
# 691 tensor(2.3306, grad_fn=<NllLossBackward0>)
# 692 tensor(2.3136, grad_fn=<NllLossBackward0>)
# 693 tensor(2.3588, grad_fn=<NllLossBackward0>)
# 694 tensor(2.3747, grad_fn=<NllLossBackward0>)
# 695 tensor(2.3461, grad_fn=<NllLossBackward0>)
# 696 tensor(2.3524, grad_fn=<NllLossBackward0>)
# 697 tensor(2.3308, grad_fn=<NllLossBackward0>)
# 698 tensor(2.3455, grad_fn=<NllLossBackward0>)
# 699 tensor(2.3217, grad_fn=<NllLossBackward0>)
# 700 tensor(2.3270, grad_fn=<NllLossBackward0>)
# 701 tensor(2.3571, grad_fn=<NllLossBackward0>)
# 702 tensor(2.3282, grad_fn=<NllLossBackward0>)
# 703 tensor(2.2736, grad_fn=<NllLossBackward0>)
# 704 tensor(2.3458, grad_fn=<NllLossBackward0>)
# 705 tensor(2.2873, grad_fn=<NllLossBackward0>)
# 706 tensor(2.2737, grad_fn=<NllLossBackward0>)
# 707 tensor(2.3297, grad_fn=<NllLossBackward0>)
# 708 tensor(2.2980, grad_fn=<NllLossBackward0>)
# 709 tensor(2.2915, grad_fn=<NllLossBackward0>)
# 710 tensor(2.3256, grad_fn=<NllLossBackward0>)
# 711 tensor(2.3450, grad_fn=<NllLossBackward0>)
# 712 tensor(2.3172, grad_fn=<NllLossBackward0>)
# 713 tensor(2.3239, grad_fn=<NllLossBackward0>)
# 714 tensor(2.3805, grad_fn=<NllLossBackward0>)
# 715 tensor(2.3818, grad_fn=<NllLossBackward0>)
# 716 tensor(2.3007, grad_fn=<NllLossBackward0>)
# 717 tensor(2.3449, grad_fn=<NllLossBackward0>)
# 718 tensor(2.2764, grad_fn=<NllLossBackward0>)
# 719 tensor(2.3996, grad_fn=<NllLossBackward0>)
# 720 tensor(2.2864, grad_fn=<NllLossBackward0>)
# 721 tensor(2.2839, grad_fn=<NllLossBackward0>)
# 722 tensor(2.3118, grad_fn=<NllLossBackward0>)
# 723 tensor(2.3111, grad_fn=<NllLossBackward0>)
# 724 tensor(2.3099, grad_fn=<NllLossBackward0>)
# 725 tensor(2.3275, grad_fn=<NllLossBackward0>)
# 726 tensor(2.2478, grad_fn=<NllLossBackward0>)
# 727 tensor(2.2780, grad_fn=<NllLossBackward0>)
# 728 tensor(2.3185, grad_fn=<NllLossBackward0>)
# 729 tensor(2.2881, grad_fn=<NllLossBackward0>)
# 730 tensor(2.3102, grad_fn=<NllLossBackward0>)
# 731 tensor(2.3350, grad_fn=<NllLossBackward0>)
# 732 tensor(2.3092, grad_fn=<NllLossBackward0>)
# 733 tensor(2.3456, grad_fn=<NllLossBackward0>)
# 734 tensor(2.3465, grad_fn=<NllLossBackward0>)
# 735 tensor(2.3414, grad_fn=<NllLossBackward0>)
# 736 tensor(2.4047, grad_fn=<NllLossBackward0>)
# 737 tensor(2.3705, grad_fn=<NllLossBackward0>)
# 738 tensor(2.3296, grad_fn=<NllLossBackward0>)
# 739 tensor(2.3262, grad_fn=<NllLossBackward0>)
# 740 tensor(2.2562, grad_fn=<NllLossBackward0>)
# 741 tensor(2.2481, grad_fn=<NllLossBackward0>)
# 742 tensor(2.2952, grad_fn=<NllLossBackward0>)
# 743 tensor(2.3519, grad_fn=<NllLossBackward0>)
# 744 tensor(2.3164, grad_fn=<NllLossBackward0>)
# 745 tensor(2.3229, grad_fn=<NllLossBackward0>)
# 746 tensor(2.3353, grad_fn=<NllLossBackward0>)
# 747 tensor(2.2879, grad_fn=<NllLossBackward0>)
# 748 tensor(2.3564, grad_fn=<NllLossBackward0>)
# 749 tensor(2.2810, grad_fn=<NllLossBackward0>)
# 750 tensor(2.3568, grad_fn=<NllLossBackward0>)
# 751 tensor(2.3053, grad_fn=<NllLossBackward0>)
# 752 tensor(2.3146, grad_fn=<NllLossBackward0>)
# 753 tensor(2.2799, grad_fn=<NllLossBackward0>)
# 754 tensor(2.3245, grad_fn=<NllLossBackward0>)
# 755 tensor(2.3653, grad_fn=<NllLossBackward0>)
# 756 tensor(2.3187, grad_fn=<NllLossBackward0>)
# 757 tensor(2.2818, grad_fn=<NllLossBackward0>)
# 758 tensor(2.3719, grad_fn=<NllLossBackward0>)
# 759 tensor(2.3731, grad_fn=<NllLossBackward0>)
# 760 tensor(2.3485, grad_fn=<NllLossBackward0>)
# 761 tensor(2.2746, grad_fn=<NllLossBackward0>)
# 762 tensor(2.3083, grad_fn=<NllLossBackward0>)
# 763 tensor(2.3094, grad_fn=<NllLossBackward0>)
# 764 tensor(2.3822, grad_fn=<NllLossBackward0>)
# 765 tensor(2.2614, grad_fn=<NllLossBackward0>)
# 766 tensor(2.2628, grad_fn=<NllLossBackward0>)
# 767 tensor(2.3554, grad_fn=<NllLossBackward0>)
# 768 tensor(2.3222, grad_fn=<NllLossBackward0>)
# 769 tensor(2.2929, grad_fn=<NllLossBackward0>)
# 770 tensor(2.2937, grad_fn=<NllLossBackward0>)
# 771 tensor(2.3189, grad_fn=<NllLossBackward0>)
# 772 tensor(2.3308, grad_fn=<NllLossBackward0>)
# 773 tensor(2.3279, grad_fn=<NllLossBackward0>)
# 774 tensor(2.3464, grad_fn=<NllLossBackward0>)
# 775 tensor(2.3744, grad_fn=<NllLossBackward0>)
# 776 tensor(2.2841, grad_fn=<NllLossBackward0>)
# 777 tensor(2.3112, grad_fn=<NllLossBackward0>)
# 778 tensor(2.3331, grad_fn=<NllLossBackward0>)
# 779 tensor(2.3755, grad_fn=<NllLossBackward0>)
# 780 tensor(2.3049, grad_fn=<NllLossBackward0>)
# 781 tensor(2.3172, grad_fn=<NllLossBackward0>)
# 782 tensor(2.2752, grad_fn=<NllLossBackward0>)
# 783 tensor(2.3213, grad_fn=<NllLossBackward0>)
# 784 tensor(2.3433, grad_fn=<NllLossBackward0>)
# 785 tensor(2.3407, grad_fn=<NllLossBackward0>)
# 786 tensor(2.2772, grad_fn=<NllLossBackward0>)
# 787 tensor(2.3195, grad_fn=<NllLossBackward0>)
# 788 tensor(2.3558, grad_fn=<NllLossBackward0>)
# 789 tensor(2.3101, grad_fn=<NllLossBackward0>)
# 790 tensor(2.3522, grad_fn=<NllLossBackward0>)
# 791 tensor(2.2886, grad_fn=<NllLossBackward0>)
# 792 tensor(2.2595, grad_fn=<NllLossBackward0>)
# 793 tensor(2.2708, grad_fn=<NllLossBackward0>)
# 794 tensor(2.3000, grad_fn=<NllLossBackward0>)
# 795 tensor(2.3010, grad_fn=<NllLossBackward0>)
# 796 tensor(2.2948, grad_fn=<NllLossBackward0>)
# 797 tensor(2.3250, grad_fn=<NllLossBackward0>)
# 798 tensor(2.2939, grad_fn=<NllLossBackward0>)
# 799 tensor(2.2885, grad_fn=<NllLossBackward0>)
# 800 tensor(2.2931, grad_fn=<NllLossBackward0>)
# 801 tensor(2.3418, grad_fn=<NllLossBackward0>)
# 802 tensor(2.2582, grad_fn=<NllLossBackward0>)
# 803 tensor(2.2579, grad_fn=<NllLossBackward0>)
# 804 tensor(2.3466, grad_fn=<NllLossBackward0>)
# 805 tensor(2.2455, grad_fn=<NllLossBackward0>)
# 806 tensor(2.2718, grad_fn=<NllLossBackward0>)
# 807 tensor(2.2809, grad_fn=<NllLossBackward0>)
# 808 tensor(2.3725, grad_fn=<NllLossBackward0>)
# 809 tensor(2.3281, grad_fn=<NllLossBackward0>)
# 810 tensor(2.3232, grad_fn=<NllLossBackward0>)
# 811 tensor(2.3217, grad_fn=<NllLossBackward0>)
# 812 tensor(2.3309, grad_fn=<NllLossBackward0>)
# 813 tensor(2.2535, grad_fn=<NllLossBackward0>)
# 814 tensor(2.2353, grad_fn=<NllLossBackward0>)
# 815 tensor(2.2631, grad_fn=<NllLossBackward0>)
# 816 tensor(2.2810, grad_fn=<NllLossBackward0>)
# 817 tensor(2.2208, grad_fn=<NllLossBackward0>)
# 818 tensor(2.2352, grad_fn=<NllLossBackward0>)
# 819 tensor(2.3612, grad_fn=<NllLossBackward0>)
# 820 tensor(2.3359, grad_fn=<NllLossBackward0>)
# 821 tensor(2.2670, grad_fn=<NllLossBackward0>)
# 822 tensor(2.2439, grad_fn=<NllLossBackward0>)
# 823 tensor(2.3086, grad_fn=<NllLossBackward0>)
# 824 tensor(2.3339, grad_fn=<NllLossBackward0>)
# 825 tensor(2.2718, grad_fn=<NllLossBackward0>)
# 826 tensor(2.3121, grad_fn=<NllLossBackward0>)
# 827 tensor(2.3311, grad_fn=<NllLossBackward0>)
# 828 tensor(2.2906, grad_fn=<NllLossBackward0>)
# 829 tensor(2.3256, grad_fn=<NllLossBackward0>)
# 830 tensor(2.3533, grad_fn=<NllLossBackward0>)
# 831 tensor(2.2693, grad_fn=<NllLossBackward0>)
# 832 tensor(2.3332, grad_fn=<NllLossBackward0>)
# 833 tensor(2.3008, grad_fn=<NllLossBackward0>)
# 834 tensor(2.2560, grad_fn=<NllLossBackward0>)
# 835 tensor(2.2734, grad_fn=<NllLossBackward0>)
# 836 tensor(2.2823, grad_fn=<NllLossBackward0>)
# 837 tensor(2.3301, grad_fn=<NllLossBackward0>)
# 838 tensor(2.3293, grad_fn=<NllLossBackward0>)
# 839 tensor(2.2605, grad_fn=<NllLossBackward0>)
# 840 tensor(2.3021, grad_fn=<NllLossBackward0>)
# 841 tensor(2.3422, grad_fn=<NllLossBackward0>)
# 842 tensor(2.2743, grad_fn=<NllLossBackward0>)
# 843 tensor(2.2955, grad_fn=<NllLossBackward0>)
# 844 tensor(2.4115, grad_fn=<NllLossBackward0>)
# 845 tensor(2.2853, grad_fn=<NllLossBackward0>)
# 846 tensor(2.3978, grad_fn=<NllLossBackward0>)
# 847 tensor(2.2501, grad_fn=<NllLossBackward0>)
# 848 tensor(2.2866, grad_fn=<NllLossBackward0>)
# 849 tensor(2.3416, grad_fn=<NllLossBackward0>)
# 850 tensor(2.3295, grad_fn=<NllLossBackward0>)
# 851 tensor(2.2666, grad_fn=<NllLossBackward0>)
# 852 tensor(2.2595, grad_fn=<NllLossBackward0>)
# 853 tensor(2.3291, grad_fn=<NllLossBackward0>)
# 854 tensor(2.2583, grad_fn=<NllLossBackward0>)
# 855 tensor(2.3254, grad_fn=<NllLossBackward0>)
# 856 tensor(2.3229, grad_fn=<NllLossBackward0>)
# 857 tensor(2.2502, grad_fn=<NllLossBackward0>)
# 858 tensor(2.2206, grad_fn=<NllLossBackward0>)
# 859 tensor(2.2608, grad_fn=<NllLossBackward0>)
# 860 tensor(2.2667, grad_fn=<NllLossBackward0>)
# 861 tensor(2.2702, grad_fn=<NllLossBackward0>)
# 862 tensor(2.2257, grad_fn=<NllLossBackward0>)
# 863 tensor(2.2416, grad_fn=<NllLossBackward0>)
# 864 tensor(2.3349, grad_fn=<NllLossBackward0>)
# 865 tensor(2.2276, grad_fn=<NllLossBackward0>)
# 866 tensor(2.2045, grad_fn=<NllLossBackward0>)
# 867 tensor(2.2865, grad_fn=<NllLossBackward0>)
# 868 tensor(2.2731, grad_fn=<NllLossBackward0>)
# 869 tensor(2.2843, grad_fn=<NllLossBackward0>)
# 870 tensor(2.2950, grad_fn=<NllLossBackward0>)
# 871 tensor(2.2685, grad_fn=<NllLossBackward0>)
# 872 tensor(2.2921, grad_fn=<NllLossBackward0>)
# 873 tensor(2.3220, grad_fn=<NllLossBackward0>)
# 874 tensor(2.2473, grad_fn=<NllLossBackward0>)
# 875 tensor(2.2590, grad_fn=<NllLossBackward0>)
# 876 tensor(2.2785, grad_fn=<NllLossBackward0>)
# 877 tensor(2.2906, grad_fn=<NllLossBackward0>)
# 878 tensor(2.2949, grad_fn=<NllLossBackward0>)
# 879 tensor(2.2575, grad_fn=<NllLossBackward0>)
# 880 tensor(2.3457, grad_fn=<NllLossBackward0>)
# 881 tensor(2.2932, grad_fn=<NllLossBackward0>)
# 882 tensor(2.2788, grad_fn=<NllLossBackward0>)
# 883 tensor(2.2925, grad_fn=<NllLossBackward0>)
# 884 tensor(2.2839, grad_fn=<NllLossBackward0>)
# 885 tensor(2.2393, grad_fn=<NllLossBackward0>)
# 886 tensor(2.2628, grad_fn=<NllLossBackward0>)
# 887 tensor(2.2335, grad_fn=<NllLossBackward0>)
# 888 tensor(2.2940, grad_fn=<NllLossBackward0>)
# 889 tensor(2.2719, grad_fn=<NllLossBackward0>)
# 890 tensor(2.2680, grad_fn=<NllLossBackward0>)
# 891 tensor(2.2467, grad_fn=<NllLossBackward0>)
# 892 tensor(2.2146, grad_fn=<NllLossBackward0>)
# 893 tensor(2.2890, grad_fn=<NllLossBackward0>)
# 894 tensor(2.3807, grad_fn=<NllLossBackward0>)
# 895 tensor(2.3388, grad_fn=<NllLossBackward0>)
# 896 tensor(2.2788, grad_fn=<NllLossBackward0>)
# 897 tensor(2.2901, grad_fn=<NllLossBackward0>)
# 898 tensor(2.2451, grad_fn=<NllLossBackward0>)
# 899 tensor(2.2907, grad_fn=<NllLossBackward0>)
# 900 tensor(2.3173, grad_fn=<NllLossBackward0>)
# 901 tensor(2.2690, grad_fn=<NllLossBackward0>)
# 902 tensor(2.2839, grad_fn=<NllLossBackward0>)
# 903 tensor(2.3064, grad_fn=<NllLossBackward0>)
# 904 tensor(2.1957, grad_fn=<NllLossBackward0>)
# 905 tensor(2.2643, grad_fn=<NllLossBackward0>)
# 906 tensor(2.2671, grad_fn=<NllLossBackward0>)
# 907 tensor(2.2522, grad_fn=<NllLossBackward0>)
# 908 tensor(2.2742, grad_fn=<NllLossBackward0>)
# 909 tensor(2.2707, grad_fn=<NllLossBackward0>)
# 910 tensor(2.2409, grad_fn=<NllLossBackward0>)
# 911 tensor(2.2049, grad_fn=<NllLossBackward0>)
# 912 tensor(2.3053, grad_fn=<NllLossBackward0>)
# 913 tensor(2.3459, grad_fn=<NllLossBackward0>)
# 914 tensor(2.2768, grad_fn=<NllLossBackward0>)
# 915 tensor(2.2807, grad_fn=<NllLossBackward0>)
# 916 tensor(2.2624, grad_fn=<NllLossBackward0>)
# 917 tensor(2.3450, grad_fn=<NllLossBackward0>)
# 918 tensor(2.2751, grad_fn=<NllLossBackward0>)
# 919 tensor(2.2746, grad_fn=<NllLossBackward0>)
# 920 tensor(2.3470, grad_fn=<NllLossBackward0>)
# 921 tensor(2.3544, grad_fn=<NllLossBackward0>)
# 922 tensor(2.1559, grad_fn=<NllLossBackward0>)
# 923 tensor(2.2984, grad_fn=<NllLossBackward0>)
# 924 tensor(2.3242, grad_fn=<NllLossBackward0>)
# 925 tensor(2.2829, grad_fn=<NllLossBackward0>)
# 926 tensor(2.3027, grad_fn=<NllLossBackward0>)
# 927 tensor(2.2162, grad_fn=<NllLossBackward0>)
# 928 tensor(2.2856, grad_fn=<NllLossBackward0>)
# 929 tensor(2.2020, grad_fn=<NllLossBackward0>)
# 930 tensor(2.3329, grad_fn=<NllLossBackward0>)
# 931 tensor(2.2808, grad_fn=<NllLossBackward0>)
# 932 tensor(2.2479, grad_fn=<NllLossBackward0>)
# 933 tensor(2.2325, grad_fn=<NllLossBackward0>)
# 934 tensor(2.2718, grad_fn=<NllLossBackward0>)
# 935 tensor(2.3149, grad_fn=<NllLossBackward0>)
# 936 tensor(2.2511, grad_fn=<NllLossBackward0>)
# 937 tensor(2.1803, grad_fn=<NllLossBackward0>)
# 938 tensor(2.2636, grad_fn=<NllLossBackward0>)
# 939 tensor(2.2539, grad_fn=<NllLossBackward0>)
# 940 tensor(2.1905, grad_fn=<NllLossBackward0>)
# 941 tensor(2.2313, grad_fn=<NllLossBackward0>)
# 942 tensor(2.3291, grad_fn=<NllLossBackward0>)
# 943 tensor(2.3256, grad_fn=<NllLossBackward0>)
# 944 tensor(2.2531, grad_fn=<NllLossBackward0>)
# 945 tensor(2.2592, grad_fn=<NllLossBackward0>)
# 946 tensor(2.2518, grad_fn=<NllLossBackward0>)
# 947 tensor(2.2312, grad_fn=<NllLossBackward0>)
# 948 tensor(2.2842, grad_fn=<NllLossBackward0>)
# 949 tensor(2.2268, grad_fn=<NllLossBackward0>)
# 950 tensor(2.2932, grad_fn=<NllLossBackward0>)
# 951 tensor(2.2250, grad_fn=<NllLossBackward0>)
# 952 tensor(2.3325, grad_fn=<NllLossBackward0>)
# 953 tensor(2.1920, grad_fn=<NllLossBackward0>)
# 954 tensor(2.3117, grad_fn=<NllLossBackward0>)
# 955 tensor(2.2803, grad_fn=<NllLossBackward0>)
# 956 tensor(2.2764, grad_fn=<NllLossBackward0>)
# 957 tensor(2.2257, grad_fn=<NllLossBackward0>)
# 958 tensor(2.2603, grad_fn=<NllLossBackward0>)
# 959 tensor(2.2457, grad_fn=<NllLossBackward0>)
# 960 tensor(2.2304, grad_fn=<NllLossBackward0>)
# 961 tensor(2.1812, grad_fn=<NllLossBackward0>)
# 962 tensor(2.2554, grad_fn=<NllLossBackward0>)
# 963 tensor(2.2915, grad_fn=<NllLossBackward0>)
# 964 tensor(2.2605, grad_fn=<NllLossBackward0>)
# 965 tensor(2.2323, grad_fn=<NllLossBackward0>)
# 966 tensor(2.3022, grad_fn=<NllLossBackward0>)
# 967 tensor(2.2479, grad_fn=<NllLossBackward0>)
# 968 tensor(2.1955, grad_fn=<NllLossBackward0>)
# 969 tensor(2.3452, grad_fn=<NllLossBackward0>)
# 970 tensor(2.3142, grad_fn=<NllLossBackward0>)
# 971 tensor(2.3131, grad_fn=<NllLossBackward0>)
# 972 tensor(2.2642, grad_fn=<NllLossBackward0>)
# 973 tensor(2.2606, grad_fn=<NllLossBackward0>)
# 974 tensor(2.2777, grad_fn=<NllLossBackward0>)
# 975 tensor(2.2378, grad_fn=<NllLossBackward0>)
# 976 tensor(2.2519, grad_fn=<NllLossBackward0>)
# 977 tensor(2.2388, grad_fn=<NllLossBackward0>)
# 978 tensor(2.2820, grad_fn=<NllLossBackward0>)
# 979 tensor(2.2481, grad_fn=<NllLossBackward0>)
# 980 tensor(2.2048, grad_fn=<NllLossBackward0>)
# 981 tensor(2.2316, grad_fn=<NllLossBackward0>)
# 982 tensor(2.2841, grad_fn=<NllLossBackward0>)
# 983 tensor(2.3179, grad_fn=<NllLossBackward0>)
# 984 tensor(2.2842, grad_fn=<NllLossBackward0>)
# 985 tensor(2.2352, grad_fn=<NllLossBackward0>)
# 986 tensor(2.2233, grad_fn=<NllLossBackward0>)
# 987 tensor(2.2802, grad_fn=<NllLossBackward0>)
# 988 tensor(2.2764, grad_fn=<NllLossBackward0>)
# 989 tensor(2.2593, grad_fn=<NllLossBackward0>)
# 990 tensor(2.2772, grad_fn=<NllLossBackward0>)
# 991 tensor(2.3178, grad_fn=<NllLossBackward0>)
# 992 tensor(2.3033, grad_fn=<NllLossBackward0>)
# 993 tensor(2.2504, grad_fn=<NllLossBackward0>)
# 994 tensor(2.2417, grad_fn=<NllLossBackward0>)
# 995 tensor(2.2561, grad_fn=<NllLossBackward0>)
# 996 tensor(2.2614, grad_fn=<NllLossBackward0>)
# 997 tensor(2.2587, grad_fn=<NllLossBackward0>)
# 998 tensor(2.2830, grad_fn=<NllLossBackward0>)
# 999 tensor(2.2722, grad_fn=<NllLossBackward0>)
# 1000 tensor(2.2107, grad_fn=<NllLossBackward0>)
# 1001 tensor(2.2515, grad_fn=<NllLossBackward0>)
# 1002 tensor(2.2003, grad_fn=<NllLossBackward0>)
# 1003 tensor(2.2163, grad_fn=<NllLossBackward0>)
# 1004 tensor(2.2268, grad_fn=<NllLossBackward0>)
# 1005 tensor(2.4040, grad_fn=<NllLossBackward0>)
# 1006 tensor(2.2619, grad_fn=<NllLossBackward0>)
# 1007 tensor(2.2692, grad_fn=<NllLossBackward0>)
# 1008 tensor(2.2580, grad_fn=<NllLossBackward0>)
# 1009 tensor(2.3265, grad_fn=<NllLossBackward0>)
# 1010 tensor(2.2191, grad_fn=<NllLossBackward0>)
# 1011 tensor(2.2345, grad_fn=<NllLossBackward0>)
# 1012 tensor(2.2115, grad_fn=<NllLossBackward0>)
# 1013 tensor(2.2165, grad_fn=<NllLossBackward0>)
# 1014 tensor(2.3158, grad_fn=<NllLossBackward0>)
# 1015 tensor(2.3025, grad_fn=<NllLossBackward0>)
# 1016 tensor(2.2499, grad_fn=<NllLossBackward0>)
# 1017 tensor(2.2962, grad_fn=<NllLossBackward0>)
# 1018 tensor(2.2156, grad_fn=<NllLossBackward0>)
# 1019 tensor(2.2751, grad_fn=<NllLossBackward0>)
# 1020 tensor(2.2705, grad_fn=<NllLossBackward0>)
# 1021 tensor(2.3002, grad_fn=<NllLossBackward0>)
# 1022 tensor(2.2137, grad_fn=<NllLossBackward0>)
# ...
# 2167 tensor(2.0605, grad_fn=<NllLossBackward0>)
# 2168 tensor(2.0109, grad_fn=<NllLossBackward0>)
# 2169 tensor(2.0115, grad_fn=<NllLossBackward0>)
# 2170 tensor(2.0234, grad_fn=<NllLossBackward0>)
# 2171 tensor(2.0692, grad_fn=<NllLossBackward0>)
# 2172 tensor(2.0826, grad_fn=<NllLossBackward0>)
# 2173 tensor(2.0137, grad_fn=<NllLossBackward0>)
# 2174 tensor(2.0766, grad_fn=<NllLossBackward0>)
# 2175 tensor(2.0440, grad_fn=<NllLossBackward0>)
# 2176 tensor(2.0925, grad_fn=<NllLossBackward0>)
# 2177 tensor(2.0923, grad_fn=<NllLossBackward0>)
# 2178 tensor(2.0051, grad_fn=<NllLossBackward0>)
# 2179 tensor(2.0665, grad_fn=<NllLossBackward0>)
# 2180 tensor(2.0728, grad_fn=<NllLossBackward0>)
# 2181 tensor(1.9959, grad_fn=<NllLossBackward0>)
# 2182 tensor(1.9984, grad_fn=<NllLossBackward0>)
# 2183 tensor(2.0177, grad_fn=<NllLossBackward0>)
# 2184 tensor(2.0516, grad_fn=<NllLossBackward0>)
# 2185 tensor(2.0452, grad_fn=<NllLossBackward0>)
# 2186 tensor(2.0415, grad_fn=<NllLossBackward0>)
# 2187 tensor(1.9995, grad_fn=<NllLossBackward0>)
# 2188 tensor(2.0442, grad_fn=<NllLossBackward0>)
# 2189 tensor(2.0874, grad_fn=<NllLossBackward0>)
# 2190 tensor(2.0284, grad_fn=<NllLossBackward0>)
# 2191 tensor(2.0126, grad_fn=<NllLossBackward0>)
# 2192 tensor(2.0545, grad_fn=<NllLossBackward0>)
# 2193 tensor(1.9674, grad_fn=<NllLossBackward0>)
# 2194 tensor(2.0193, grad_fn=<NllLossBackward0>)
# 2195 tensor(2.0474, grad_fn=<NllLossBackward0>)
# 2196 tensor(1.9794, grad_fn=<NllLossBackward0>)
# 2197 tensor(2.0421, grad_fn=<NllLossBackward0>)
# 2198 tensor(1.9352, grad_fn=<NllLossBackward0>)
# 2199 tensor(2.0117, grad_fn=<NllLossBackward0>)
# 2200 tensor(2.0657, grad_fn=<NllLossBackward0>)
# 2201 tensor(2.0727, grad_fn=<NllLossBackward0>)
# 2202 tensor(1.9878, grad_fn=<NllLossBackward0>)
# 2203 tensor(2.0725, grad_fn=<NllLossBackward0>)
# 2204 tensor(2.0406, grad_fn=<NllLossBackward0>)
# 2205 tensor(2.0611, grad_fn=<NllLossBackward0>)
# 2206 tensor(2.0832, grad_fn=<NllLossBackward0>)
# 2207 tensor(1.9784, grad_fn=<NllLossBackward0>)
# 2208 tensor(1.8978, grad_fn=<NllLossBackward0>)
# 2209 tensor(1.9904, grad_fn=<NllLossBackward0>)
# 2210 tensor(2.0041, grad_fn=<NllLossBackward0>)
# 2211 tensor(2.0480, grad_fn=<NllLossBackward0>)
# 2212 tensor(1.9689, grad_fn=<NllLossBackward0>)
# 2213 tensor(2.0313, grad_fn=<NllLossBackward0>)
# 2214 tensor(1.9379, grad_fn=<NllLossBackward0>)
# 2215 tensor(2.0343, grad_fn=<NllLossBackward0>)
# 2216 tensor(2.0133, grad_fn=<NllLossBackward0>)
# 2217 tensor(2.0260, grad_fn=<NllLossBackward0>)
# 2218 tensor(2.0938, grad_fn=<NllLossBackward0>)
# 2219 tensor(2.0793, grad_fn=<NllLossBackward0>)
# 2220 tensor(2.0638, grad_fn=<NllLossBackward0>)
# 2221 tensor(2.0820, grad_fn=<NllLossBackward0>)
# 2222 tensor(2.0335, grad_fn=<NllLossBackward0>)
# 2223 tensor(2.0493, grad_fn=<NllLossBackward0>)
# 2224 tensor(1.9839, grad_fn=<NllLossBackward0>)
# 2225 tensor(2.0018, grad_fn=<NllLossBackward0>)
# 2226 tensor(2.0880, grad_fn=<NllLossBackward0>)
# 2227 tensor(2.0787, grad_fn=<NllLossBackward0>)
# 2228 tensor(2.0169, grad_fn=<NllLossBackward0>)
# 2229 tensor(2.0410, grad_fn=<NllLossBackward0>)
# 2230 tensor(2.0070, grad_fn=<NllLossBackward0>)
# 2231 tensor(1.9700, grad_fn=<NllLossBackward0>)
# 2232 tensor(1.9950, grad_fn=<NllLossBackward0>)
# 2233 tensor(1.9855, grad_fn=<NllLossBackward0>)
# 2234 tensor(2.0035, grad_fn=<NllLossBackward0>)
# 2235 tensor(2.0706, grad_fn=<NllLossBackward0>)
# 2236 tensor(2.0540, grad_fn=<NllLossBackward0>)
# 2237 tensor(2.0004, grad_fn=<NllLossBackward0>)
# 2238 tensor(2.0668, grad_fn=<NllLossBackward0>)
# 2239 tensor(2.0467, grad_fn=<NllLossBackward0>)
# 2240 tensor(1.9658, grad_fn=<NllLossBackward0>)
# 2241 tensor(2.0434, grad_fn=<NllLossBackward0>)
# 2242 tensor(2.0528, grad_fn=<NllLossBackward0>)
# 2243 tensor(1.9805, grad_fn=<NllLossBackward0>)
# 2244 tensor(1.9677, grad_fn=<NllLossBackward0>)
# 2245 tensor(1.9891, grad_fn=<NllLossBackward0>)
# 2246 tensor(1.9578, grad_fn=<NllLossBackward0>)
# 2247 tensor(2.0492, grad_fn=<NllLossBackward0>)
# 2248 tensor(2.0159, grad_fn=<NllLossBackward0>)
# 2249 tensor(1.9753, grad_fn=<NllLossBackward0>)
# 2250 tensor(2.0021, grad_fn=<NllLossBackward0>)
# 2251 tensor(2.0863, grad_fn=<NllLossBackward0>)
# 2252 tensor(2.0635, grad_fn=<NllLossBackward0>)
# 2253 tensor(2.0284, grad_fn=<NllLossBackward0>)
# 2254 tensor(2.0407, grad_fn=<NllLossBackward0>)
# 2255 tensor(2.0942, grad_fn=<NllLossBackward0>)
# 2256 tensor(2.0415, grad_fn=<NllLossBackward0>)
# 2257 tensor(2.0156, grad_fn=<NllLossBackward0>)
# 2258 tensor(1.8843, grad_fn=<NllLossBackward0>)
# 2259 tensor(1.9852, grad_fn=<NllLossBackward0>)
# 2260 tensor(1.9922, grad_fn=<NllLossBackward0>)
# 2261 tensor(2.0799, grad_fn=<NllLossBackward0>)
# 2262 tensor(1.9787, grad_fn=<NllLossBackward0>)
# 2263 tensor(2.0332, grad_fn=<NllLossBackward0>)
# 2264 tensor(2.1073, grad_fn=<NllLossBackward0>)
# 2265 tensor(2.0108, grad_fn=<NllLossBackward0>)
# 2266 tensor(2.0175, grad_fn=<NllLossBackward0>)
# 2267 tensor(1.9825, grad_fn=<NllLossBackward0>)
# 2268 tensor(1.9572, grad_fn=<NllLossBackward0>)
# 2269 tensor(1.9519, grad_fn=<NllLossBackward0>)
# 2270 tensor(2.0365, grad_fn=<NllLossBackward0>)
# 2271 tensor(1.9721, grad_fn=<NllLossBackward0>)
# 2272 tensor(2.0091, grad_fn=<NllLossBackward0>)
# 2273 tensor(2.0226, grad_fn=<NllLossBackward0>)
# 2274 tensor(1.9611, grad_fn=<NllLossBackward0>)
# 2275 tensor(1.9179, grad_fn=<NllLossBackward0>)
# 2276 tensor(1.9643, grad_fn=<NllLossBackward0>)
# 2277 tensor(2.0137, grad_fn=<NllLossBackward0>)
# 2278 tensor(2.0471, grad_fn=<NllLossBackward0>)
# 2279 tensor(1.9315, grad_fn=<NllLossBackward0>)
# 2280 tensor(1.9795, grad_fn=<NllLossBackward0>)
# 2281 tensor(1.9967, grad_fn=<NllLossBackward0>)
# 2282 tensor(2.1005, grad_fn=<NllLossBackward0>)
# 2283 tensor(2.0341, grad_fn=<NllLossBackward0>)
# 2284 tensor(1.9936, grad_fn=<NllLossBackward0>)
# 2285 tensor(1.9236, grad_fn=<NllLossBackward0>)
# 2286 tensor(1.9602, grad_fn=<NllLossBackward0>)
# 2287 tensor(1.9623, grad_fn=<NllLossBackward0>)
# 2288 tensor(2.0234, grad_fn=<NllLossBackward0>)
# 2289 tensor(1.9775, grad_fn=<NllLossBackward0>)
# 2290 tensor(2.0465, grad_fn=<NllLossBackward0>)
# 2291 tensor(2.0371, grad_fn=<NllLossBackward0>)
# 2292 tensor(2.0104, grad_fn=<NllLossBackward0>)
# 2293 tensor(2.0589, grad_fn=<NllLossBackward0>)
# 2294 tensor(2.0587, grad_fn=<NllLossBackward0>)
# 2295 tensor(2.0150, grad_fn=<NllLossBackward0>)
# 2296 tensor(2.0131, grad_fn=<NllLossBackward0>)
# 2297 tensor(2.0587, grad_fn=<NllLossBackward0>)
# 2298 tensor(1.9984, grad_fn=<NllLossBackward0>)
# 2299 tensor(2.0100, grad_fn=<NllLossBackward0>)
# 2300 tensor(2.0820, grad_fn=<NllLossBackward0>)
# 2301 tensor(1.9828, grad_fn=<NllLossBackward0>)
# 2302 tensor(1.9673, grad_fn=<NllLossBackward0>)
# 2303 tensor(2.1417, grad_fn=<NllLossBackward0>)
# 2304 tensor(2.0426, grad_fn=<NllLossBackward0>)
# 2305 tensor(2.1260, grad_fn=<NllLossBackward0>)
# 2306 tensor(2.0353, grad_fn=<NllLossBackward0>)
# 2307 tensor(2.0074, grad_fn=<NllLossBackward0>)
# 2308 tensor(2.0317, grad_fn=<NllLossBackward0>)
# 2309 tensor(2.0278, grad_fn=<NllLossBackward0>)
# 2310 tensor(2.0533, grad_fn=<NllLossBackward0>)
# 2311 tensor(2.0830, grad_fn=<NllLossBackward0>)
# 2312 tensor(2.0137, grad_fn=<NllLossBackward0>)
# 2313 tensor(2.0083, grad_fn=<NllLossBackward0>)
# 2314 tensor(1.9954, grad_fn=<NllLossBackward0>)
# 2315 tensor(2.0015, grad_fn=<NllLossBackward0>)
# 2316 tensor(1.9661, grad_fn=<NllLossBackward0>)
# 2317 tensor(2.0019, grad_fn=<NllLossBackward0>)
# 2318 tensor(2.0247, grad_fn=<NllLossBackward0>)
# 2319 tensor(1.9695, grad_fn=<NllLossBackward0>)
# 2320 tensor(2.0251, grad_fn=<NllLossBackward0>)
# 2321 tensor(2.0536, grad_fn=<NllLossBackward0>)
# 2322 tensor(2.0538, grad_fn=<NllLossBackward0>)
# 2323 tensor(1.9868, grad_fn=<NllLossBackward0>)
# 2324 tensor(1.9999, grad_fn=<NllLossBackward0>)
# 2325 tensor(1.9555, grad_fn=<NllLossBackward0>)
# 2326 tensor(1.9234, grad_fn=<NllLossBackward0>)
# 2327 tensor(2.0264, grad_fn=<NllLossBackward0>)
# 2328 tensor(2.0465, grad_fn=<NllLossBackward0>)
# 2329 tensor(2.0757, grad_fn=<NllLossBackward0>)
# 2330 tensor(2.0193, grad_fn=<NllLossBackward0>)
# 2331 tensor(1.9660, grad_fn=<NllLossBackward0>)
# 2332 tensor(2.0412, grad_fn=<NllLossBackward0>)
# 2333 tensor(2.0198, grad_fn=<NllLossBackward0>)
# 2334 tensor(1.9963, grad_fn=<NllLossBackward0>)
# 2335 tensor(1.9779, grad_fn=<NllLossBackward0>)
# 2336 tensor(2.0408, grad_fn=<NllLossBackward0>)
# 2337 tensor(2.0030, grad_fn=<NllLossBackward0>)
# 2338 tensor(1.9502, grad_fn=<NllLossBackward0>)
# 2339 tensor(2.0637, grad_fn=<NllLossBackward0>)
# 2340 tensor(1.9676, grad_fn=<NllLossBackward0>)
# 2341 tensor(1.9909, grad_fn=<NllLossBackward0>)
# 2342 tensor(2.0520, grad_fn=<NllLossBackward0>)
# 2343 tensor(1.9430, grad_fn=<NllLossBackward0>)
# 2344 tensor(2.0782, grad_fn=<NllLossBackward0>)
# 2345 tensor(2.0341, grad_fn=<NllLossBackward0>)
# 2346 tensor(2.0231, grad_fn=<NllLossBackward0>)
# 2347 tensor(1.9648, grad_fn=<NllLossBackward0>)
# 2348 tensor(1.9205, grad_fn=<NllLossBackward0>)
# 2349 tensor(2.0169, grad_fn=<NllLossBackward0>)
# 2350 tensor(1.9790, grad_fn=<NllLossBackward0>)
# 2351 tensor(1.9305, grad_fn=<NllLossBackward0>)
# 2352 tensor(1.9846, grad_fn=<NllLossBackward0>)
# 2353 tensor(1.9816, grad_fn=<NllLossBackward0>)
# 2354 tensor(1.9435, grad_fn=<NllLossBackward0>)
# 2355 tensor(2.0482, grad_fn=<NllLossBackward0>)
# 2356 tensor(2.0136, grad_fn=<NllLossBackward0>)
# 2357 tensor(2.0659, grad_fn=<NllLossBackward0>)
# 2358 tensor(2.0475, grad_fn=<NllLossBackward0>)
# 2359 tensor(2.0453, grad_fn=<NllLossBackward0>)
# 2360 tensor(1.9858, grad_fn=<NllLossBackward0>)
# 2361 tensor(2.0214, grad_fn=<NllLossBackward0>)
# 2362 tensor(2.0535, grad_fn=<NllLossBackward0>)
# 2363 tensor(1.9808, grad_fn=<NllLossBackward0>)
# 2364 tensor(2.0336, grad_fn=<NllLossBackward0>)
# 2365 tensor(1.9604, grad_fn=<NllLossBackward0>)
# 2366 tensor(1.9924, grad_fn=<NllLossBackward0>)
# 2367 tensor(2.0694, grad_fn=<NllLossBackward0>)
# 2368 tensor(2.0375, grad_fn=<NllLossBackward0>)
# 2369 tensor(2.0833, grad_fn=<NllLossBackward0>)
# 2370 tensor(1.9480, grad_fn=<NllLossBackward0>)
# 2371 tensor(2.0176, grad_fn=<NllLossBackward0>)
# 2372 tensor(1.9487, grad_fn=<NllLossBackward0>)
# 2373 tensor(1.9927, grad_fn=<NllLossBackward0>)
# 2374 tensor(1.9877, grad_fn=<NllLossBackward0>)
# 2375 tensor(2.1275, grad_fn=<NllLossBackward0>)
# 2376 tensor(1.9688, grad_fn=<NllLossBackward0>)
# 2377 tensor(2.0230, grad_fn=<NllLossBackward0>)
# 2378 tensor(2.0463, grad_fn=<NllLossBackward0>)
# 2379 tensor(2.0033, grad_fn=<NllLossBackward0>)
# 2380 tensor(1.9986, grad_fn=<NllLossBackward0>)
# 2381 tensor(2.0034, grad_fn=<NllLossBackward0>)
# 2382 tensor(2.0387, grad_fn=<NllLossBackward0>)
# 2383 tensor(1.9977, grad_fn=<NllLossBackward0>)
# 2384 tensor(2.0084, grad_fn=<NllLossBackward0>)
# 2385 tensor(2.0535, grad_fn=<NllLossBackward0>)
# 2386 tensor(2.0016, grad_fn=<NllLossBackward0>)
# 2387 tensor(2.0447, grad_fn=<NllLossBackward0>)
# 2388 tensor(1.9312, grad_fn=<NllLossBackward0>)
# 2389 tensor(1.9473, grad_fn=<NllLossBackward0>)
# 2390 tensor(2.0482, grad_fn=<NllLossBackward0>)
# 2391 tensor(1.9918, grad_fn=<NllLossBackward0>)
# 2392 tensor(2.0305, grad_fn=<NllLossBackward0>)
# 2393 tensor(2.0341, grad_fn=<NllLossBackward0>)
# 2394 tensor(2.0973, grad_fn=<NllLossBackward0>)
# 2395 tensor(2.0380, grad_fn=<NllLossBackward0>)
# 2396 tensor(2.0083, grad_fn=<NllLossBackward0>)
# 2397 tensor(2.0602, grad_fn=<NllLossBackward0>)
# 2398 tensor(1.9553, grad_fn=<NllLossBackward0>)
# 2399 tensor(1.9678, grad_fn=<NllLossBackward0>)
# 2400 tensor(2.0662, grad_fn=<NllLossBackward0>)
# 2401 tensor(1.9668, grad_fn=<NllLossBackward0>)
# 2402 tensor(1.9995, grad_fn=<NllLossBackward0>)
# 2403 tensor(1.9641, grad_fn=<NllLossBackward0>)
# 2404 tensor(2.0123, grad_fn=<NllLossBackward0>)
# 2405 tensor(1.9913, grad_fn=<NllLossBackward0>)
# 2406 tensor(1.9536, grad_fn=<NllLossBackward0>)
# 2407 tensor(1.9867, grad_fn=<NllLossBackward0>)
# 2408 tensor(2.0128, grad_fn=<NllLossBackward0>)
# 2409 tensor(1.9432, grad_fn=<NllLossBackward0>)
# 2410 tensor(1.9368, grad_fn=<NllLossBackward0>)
# 2411 tensor(2.0773, grad_fn=<NllLossBackward0>)
# 2412 tensor(1.9624, grad_fn=<NllLossBackward0>)
# 2413 tensor(1.9573, grad_fn=<NllLossBackward0>)
# 2414 tensor(1.9638, grad_fn=<NllLossBackward0>)
# 2415 tensor(2.0726, grad_fn=<NllLossBackward0>)
# 2416 tensor(1.9981, grad_fn=<NllLossBackward0>)
# 2417 tensor(2.0338, grad_fn=<NllLossBackward0>)
# 2418 tensor(2.0567, grad_fn=<NllLossBackward0>)
# 2419 tensor(2.0231, grad_fn=<NllLossBackward0>)
# 2420 tensor(2.0316, grad_fn=<NllLossBackward0>)
# 2421 tensor(1.9674, grad_fn=<NllLossBackward0>)
# 2422 tensor(1.9819, grad_fn=<NllLossBackward0>)
# 2423 tensor(2.0442, grad_fn=<NllLossBackward0>)
# 2424 tensor(2.0062, grad_fn=<NllLossBackward0>)
# 2425 tensor(2.0461, grad_fn=<NllLossBackward0>)
# 2426 tensor(1.9987, grad_fn=<NllLossBackward0>)
# 2427 tensor(1.9771, grad_fn=<NllLossBackward0>)
# 2428 tensor(2.0958, grad_fn=<NllLossBackward0>)
# 2429 tensor(2.0439, grad_fn=<NllLossBackward0>)
# 2430 tensor(2.0407, grad_fn=<NllLossBackward0>)
# 2431 tensor(2.0221, grad_fn=<NllLossBackward0>)
# 2432 tensor(2.0375, grad_fn=<NllLossBackward0>)
# 2433 tensor(1.9912, grad_fn=<NllLossBackward0>)
# 2434 tensor(1.9751, grad_fn=<NllLossBackward0>)
# 2435 tensor(1.9995, grad_fn=<NllLossBackward0>)
# 2436 tensor(2.0452, grad_fn=<NllLossBackward0>)
# 2437 tensor(1.9649, grad_fn=<NllLossBackward0>)
# 2438 tensor(1.9534, grad_fn=<NllLossBackward0>)
# 2439 tensor(1.9890, grad_fn=<NllLossBackward0>)
# 2440 tensor(1.9542, grad_fn=<NllLossBackward0>)
# 2441 tensor(1.9413, grad_fn=<NllLossBackward0>)
# 2442 tensor(1.9933, grad_fn=<NllLossBackward0>)
# 2443 tensor(1.9835, grad_fn=<NllLossBackward0>)
# 2444 tensor(2.0079, grad_fn=<NllLossBackward0>)
# 2445 tensor(2.0438, grad_fn=<NllLossBackward0>)
# 2446 tensor(2.0156, grad_fn=<NllLossBackward0>)
# 2447 tensor(1.9441, grad_fn=<NllLossBackward0>)
# 2448 tensor(1.9609, grad_fn=<NllLossBackward0>)
# 2449 tensor(1.9678, grad_fn=<NllLossBackward0>)
# 2450 tensor(2.0105, grad_fn=<NllLossBackward0>)
# 2451 tensor(1.9487, grad_fn=<NllLossBackward0>)
# 2452 tensor(1.9535, grad_fn=<NllLossBackward0>)
# 2453 tensor(1.9727, grad_fn=<NllLossBackward0>)
# 2454 tensor(1.9916, grad_fn=<NllLossBackward0>)
# 2455 tensor(2.0383, grad_fn=<NllLossBackward0>)
# 2456 tensor(1.9781, grad_fn=<NllLossBackward0>)
# 2457 tensor(1.9383, grad_fn=<NllLossBackward0>)
# 2458 tensor(1.9964, grad_fn=<NllLossBackward0>)
# 2459 tensor(2.0524, grad_fn=<NllLossBackward0>)
# 2460 tensor(1.9935, grad_fn=<NllLossBackward0>)
# 2461 tensor(1.9175, grad_fn=<NllLossBackward0>)
# 2462 tensor(1.9044, grad_fn=<NllLossBackward0>)
# 2463 tensor(1.9949, grad_fn=<NllLossBackward0>)
# 2464 tensor(1.9786, grad_fn=<NllLossBackward0>)
# 2465 tensor(1.9834, grad_fn=<NllLossBackward0>)
# 2466 tensor(2.0015, grad_fn=<NllLossBackward0>)
# 2467 tensor(1.9732, grad_fn=<NllLossBackward0>)
# 2468 tensor(2.0025, grad_fn=<NllLossBackward0>)
# 2469 tensor(2.0476, grad_fn=<NllLossBackward0>)
# 2470 tensor(1.9402, grad_fn=<NllLossBackward0>)
# 2471 tensor(1.9448, grad_fn=<NllLossBackward0>)
# 2472 tensor(2.0016, grad_fn=<NllLossBackward0>)
# 2473 tensor(2.0922, grad_fn=<NllLossBackward0>)
# 2474 tensor(2.0184, grad_fn=<NllLossBackward0>)
# 2475 tensor(1.9723, grad_fn=<NllLossBackward0>)
# 2476 tensor(1.9768, grad_fn=<NllLossBackward0>)
# 2477 tensor(2.0904, grad_fn=<NllLossBackward0>)
# 2478 tensor(1.9098, grad_fn=<NllLossBackward0>)
# 2479 tensor(2.0021, grad_fn=<NllLossBackward0>)
# 2480 tensor(1.9504, grad_fn=<NllLossBackward0>)
# 2481 tensor(2.0007, grad_fn=<NllLossBackward0>)
# 2482 tensor(1.9855, grad_fn=<NllLossBackward0>)
# 2483 tensor(1.9407, grad_fn=<NllLossBackward0>)
# 2484 tensor(1.9389, grad_fn=<NllLossBackward0>)
# 2485 tensor(1.9758, grad_fn=<NllLossBackward0>)
# 2486 tensor(1.9686, grad_fn=<NllLossBackward0>)
# 2487 tensor(2.0196, grad_fn=<NllLossBackward0>)
# 2488 tensor(1.8875, grad_fn=<NllLossBackward0>)
# 2489 tensor(1.9441, grad_fn=<NllLossBackward0>)
# 2490 tensor(2.0362, grad_fn=<NllLossBackward0>)
# 2491 tensor(2.0239, grad_fn=<NllLossBackward0>)
# 2492 tensor(2.0488, grad_fn=<NllLossBackward0>)
# 2493 tensor(2.0315, grad_fn=<NllLossBackward0>)
# 2494 tensor(1.9778, grad_fn=<NllLossBackward0>)
# 2495 tensor(2.0574, grad_fn=<NllLossBackward0>)
# 2496 tensor(1.9775, grad_fn=<NllLossBackward0>)
# 2497 tensor(1.9635, grad_fn=<NllLossBackward0>)
# 2498 tensor(1.9697, grad_fn=<NllLossBackward0>)
# 2499 tensor(2.0347, grad_fn=<NllLossBackward0>)

# %%
print(m.prompt('t', 250))
# Out:
# tensor([[58]])
# to warrruck of wheman come. Gor too, they of whe with ulintase;
# Thisch somw whis'd you.
# Thorewe hat morre, leger, alese ret of waltus,
# The, you tid knore, him kine.
#
# QUCUTUTOLO:
# Jhat him! i'l luff ne thein atre han do;
# And not bether benfuterbr to hou
